# %% [markdown]
# # 1. Google Colaboratory Tutorial
#
# Before we step further google colaboratory, we should know how the colab works.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Overview of Colaboratory Features
#
# https://colab.research.google.com/notebooks/basic_features_overview.ipynb

# %% [markdown]
# # Some important issues you should know
#
#
# ##* Charge
#
# Free.
#
# ##* Hardware resource management
#
# WHen you are using one instance, 90 min max for idle time , 12 hours for running (they will shutdown the instance then). Apparently not for heavy use, rather educational / trial. Google prepares [google cloud](https://cloud.google.com/ or [AWS](https://aws.amazon.com/jp/) if you seriously think of massive runs.
#
# As of Oct. 2019, it seems users can run multiple instances in parallel ! [(source](https://stackoverflow.com/questions/58411527/can-multiple-colab-notebooks-share-the-same-runtime))
#
# But probably you will have lower priority for a certain period once you overuse the system. Think [Colab Pro](https://colab.research.google.com/signup) if you need a bit more computation (note that it is quite different from google cloud / AWS).
#
# ##* CPU only / with GPU / with TPU
#
# You can pick up three types of instances on connecting an instance from a colab notebook. Default is CPU only. Change the runtime type if you need GPU or TPU. (TPU has been available since 2018/09.)
# As for this course, basic CPU-only version is sufficient.
#
# ##* System info
#
# Here are some tips to get system info.
# You are the root (= You can change system files too).
# That's why you can install any libraries on a colab notebook.

# %%
# !echo "--- Distribution"
# !cat /etc/issue
# !echo "--- CPUs are"
# !cat /proc/cpuinfo | grep "model name"
# !echo "--- Memory size is"
# !free -h
# !echo "--- Disk is"
# !df -h /
# !echo "--- GPU (if assigned)"
# !nvidia-smi
# !echo "--- You are logging in as ..."
# !whoami
# !echo "--- How long this instance is running"
# !uptime
# !echo "--- IP v4 address"
# !ip -brief -4 -c address
# !echo "--- IP v4 routing"
# !ip -brief -4 -c route
# !echo "--- IP v4 global address"
# !curl ipecho.net/plain
# Out:
# --- Distribution
# Ubuntu 22.04.5 LTS \n \l
#
# --- CPUs are
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# --- Memory size is
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       728Mi       8.5Gi       2.0Mi       3.5Gi        11Gi
# Swap:             0B          0B          0B
# --- Disk is
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   47G   66G  42% /
# --- GPU (if assigned)
# Thu Aug  6 06:22:34 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# --- You are logging in as ...
# root
# --- How long this instance is running
#  06:22:35 up 2 min,  0 users,  load average: 0.39, 0.25, 0.10
# --- IP v4 address
# lo               UNKNOWN        127.0.0.1/8
# eth0@if8         UP             172.28.0.12/16
# --- IP v4 routing
# default via 172.28.0.1 dev eth0
# 172.28.0.0/16 dev eth0 proto kernel scope link src 172.28.0.12
# --- IP v4 global address
# 34.168.154.236

# %% [markdown]
# # Code snipets
#
# Especially when you think of how to write a code which is related to the google colaboratory system, ask them to "code snipet" first (then you may wonder asking questions on the internet, but don't do that at first!)
#
# 1. Menu / Help / Query code snipet
# 2. You will see a strip next to the colab notebook pain
# 3. Make a query
# 4. Some answers are shown at the bottom.
# 5. I RECOMMEND YOU to "show source notebook" before you take it!!
# 6. Check samples too (if available)
# 7. Then "insert" (or click right arrow)" to import that code to your notebook.
# 8. Edit if needed.
# 9. Run the code cell and enjoy!
#
# Here are very popular snipets you may be interested in.
# Make a query and give it a try!
#
# * Adding form fields
# * Camera capture
# * Cross-output communication
# * display Javascript to execute JavaScript from Python
# * Downloading files or importing data from Google Drive

# %% [markdown]
# # AI cooked
#
# One of the good points of the Google colaboratory is that the maintainers  have pre-installed the latest versions of the major AI/ML tools. (If not, you can install by your hands since you are the root.)

# %% [markdown]
# For example, libraries on python language are:

# %%
# !echo "How many libraries available? ---"
# !pip list | wc -l
# Out:
# How many libraries available? ---
# 706

# %%
# !echo "List all all the libraries ---"
# !pip list
# Out:
# List all all the libraries ---
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                2.4.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.1
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.0
# altair                                5.5.0
# annotated-doc                         0.0.4
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# apsw                                  3.53.3.1
# apswutils                             0.1.2
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  25.1.0
# array_record                          0.8.3
# arrow                                 1.4.0
# arviz                                 0.22.0
# astropy                               7.2.2
# astropy-iers-data                     0.2026.7.13.0.54.2
# astunparse                            1.6.3
# atpublic                              5.1
# attrs                                 26.1.0
# audioread                             3.1.0
# Authlib                               1.7.2
# autograd                              1.9.1
# babel                                 2.18.0
# backcall                              0.2.0
# beartype                              0.22.9
# beautifulsoup4                        4.13.5
# betterproto                           2.0.0b6
# bigframes                             2.42.0
# bigquery-magics                       0.14.0
# bleach                                6.4.0
# blinker                               1.9.0
# blis                                  1.3.3
# blobfile                              3.2.0
# blosc2                                4.8.0
# bokeh                                 3.8.2
# Bottleneck                            1.4.2
# bqplot                                0.12.47
# branca                                0.8.2
# brotli                                1.2.0
# CacheControl                          0.14.4
# cachetools                            6.2.6
# catalogue                             2.0.10
# certifi                               2026.6.17
# cffi                                  2.1.0
# chardet                               5.2.0
# charset-normalizer                    3.4.9
# clarabel                              0.11.1
# click                                 8.4.2
# cligj                                 0.7.2
# cloudpathlib                          0.24.0
# cloudpickle                           3.1.2
# cmake                                 3.31.10
# cmdstanpy                             1.3.0
# colorcet                              3.2.1
# colorlover                            0.3.0
# community                             1.0.0b1
# confection                            1.3.3
# cons                                  0.4.7
# contourpy                             1.3.3
# cramjam                               2.11.0
# cryptography                          49.0.0
# cucim-cu12                            26.2.0
# cuda-bindings                         12.9.7
# cuda-core                             0.3.2
# cuda-pathfinder                       1.5.6
# cuda-python                           12.9.7
# cuda-toolkit                          12.8.1
# cudf-cu12                             26.2.1
# cudf-polars-cu12                      26.2.1
# cufflinks                             0.17.3
# cuml-cu12                             26.2.0
# cupy-cuda12x                          14.0.1
# curl_cffi                             0.15.0
# cuvs-cu12                             26.2.0
# cvxopt                                1.3.2
# cvxpy                                 1.6.7
# cycler                                0.12.1
# cyipopt                               1.5.0
# cymem                                 2.0.13
# Cython                                3.0.12
# dask                                  2026.1.1
# dask-cuda                             26.2.0
# dask-cudf-cu12                        26.2.1
# dataproc-spark-connect                1.1.0
# datasets                              4.0.0
# db-dtypes                             1.7.1
# dbus-python                           1.2.18
# debugpy                               1.8.15
# decorator                             4.4.2
# defusedxml                            0.7.1
# deprecation                           2.1.0
# diffusers                             0.39.0
# dill                                  0.3.8
# distributed                           2026.1.1
# distributed-ucxx-cu12                 0.48.0
# distro                                1.9.0
# dlib                                  19.24.6
# dm-tree                               0.1.10
# docstring_parser                      0.18.0
# docutils                              0.21.2
# dopamine_rl                           4.1.2
# duckdb                                1.3.2
# earthengine-api                       1.7.35
# easydict                              1.13
# editdistance                          0.8.1
# eerepr                                0.1.2
# einops                                0.8.2
# en_core_web_sm                        3.8.0
# entrypoints                           0.4
# esda                                  2.9.0
# et_xmlfile                            2.0.0
# etils                                 1.14.0
# etuples                               0.3.10
# Farama-Notifications                  0.0.6
# fastai                                2.8.7
# fastapi                               0.139.0
# fastcore                              2.0.5
# fastdownload                          0.0.7
# fastjsonschema                        2.21.2
# fastlite                              0.2.4
# fastprogress                          1.1.6
# fasttransform                         0.0.2
# filelock                              3.29.7
# firebase-admin                        6.9.0
# Flask                                 3.1.3
# flatbuffers                           25.12.19
# flax                                  0.11.2
# folium                                0.20.0
# fonttools                             4.63.0
# fqdn                                  1.5.1
# frozendict                            2.4.7
# frozenlist                            1.8.0
# fsspec                                2025.3.0
# future                                1.0.0
# gast                                  0.7.0
# gcsfs                                 2025.3.0
# GDAL                                  3.8.4
# gdown                                 5.2.2
# geemap                                0.38.3
# geocoder                              1.38.1
# geographiclib                         2.1
# geopandas                             1.1.4
# geopy                                 2.4.1
# giddy                                 2.3.6
# gin-config                            0.5.0
# gitdb                                 4.0.12
# GitPython                             3.1.51
# glob2                                 0.7
# google                                3.0.0
# google-adk                            2.4.0
# google-ai-generativelanguage          0.6.15
# google-api-core                       2.30.3
# google-api-python-client              2.198.0
# google-auth                           2.49.0
# google-auth-httplib2                  0.4.0
# google-auth-oauthlib                  1.4.0
# google-cloud-bigquery                 3.42.2
# google-cloud-bigquery-connection      1.22.0
# google-cloud-bigquery-storage         2.39.0
# google-cloud-core                     2.6.0
# google-cloud-dataproc                 5.28.0
# google-cloud-datastore                2.25.0
# google-cloud-firestore                2.27.0
# google-cloud-functions                1.24.0
# google-cloud-language                 2.21.0
# google-cloud-monitoring               2.31.0
# google-cloud-resource-manager         1.18.0
# google-cloud-spanner                  3.68.0
# google-cloud-storage                  3.13.0
# google-cloud-translate                3.27.0
# google-colab                          1.0.0
# google-crc32c                         1.8.0
# google-genai                          2.11.0
# google-generativeai                   0.8.6
# google-pasta                          0.2.0
# google-resumable-media                2.10.0
# googleapis-common-protos              1.75.0
# googledrivedownloader                 1.1.0
# gradio                                6.20.0
# gradio_client                         2.5.0
# grain                                 0.2.18
# graphviz                              0.21
# greenlet                              3.5.3
# groovy                                0.1.2
# grpc-google-iam-v1                    0.14.4
# grpc-interceptor                      0.15.4
# grpcio                                1.82.1
# grpcio-status                         1.71.2
# grpclib                               0.4.9
# gspread                               6.2.1
# gspread-dataframe                     4.0.0
# gym                                   0.25.2
# gym-notices                           0.1.0
# gymnasium                             1.3.0
# h11                                   0.16.0
# h2                                    4.3.0
# h5netcdf                              1.8.1
# h5py                                  3.16.0
# hdbscan                               0.8.44
# hf-gradio                             0.4.1
# hf-xet                                1.5.1
# highspy                               1.15.1
# holidays                              0.100
# holoviews                             1.23.1
# hpack                                 4.2.0
# html5lib                              1.1
# httpcore                              1.0.9
# httpcore2                             2.5.0
# httpimport                            1.4.1
# httplib2                              0.32.0
# httptools                             0.8.0
# httpx                                 0.28.1
# httpx2                                2.5.0
# huggingface_hub                       1.23.0
# humanize                              4.16.0
# hyperframe                            6.1.0
# hyperopt                              0.2.7
# ibis-framework                        9.5.0
# idna                                  3.18
# ImageIO                               2.37.3
# imageio-ffmpeg                        0.6.0
# imagesize                             2.0.0
# imbalanced-learn                      0.14.2
# immutabledict                         4.3.1
# importlib_metadata                    9.0.0
# importlib_resources                   7.1.0
# imutils                               0.5.4
# inequality                            1.1.2
# inflect                               7.5.0
# iniconfig                             2.3.0
# intel-cmplr-lib-ur                    2025.3.3
# intel-openmp                          2025.3.3
# ipyevents                             2.0.4
# ipyfilechooser                        0.6.0
# ipykernel                             6.17.1
# ipyleaflet                            0.20.0
# ipyparallel                           8.8.0
# ipython                               7.34.0
# ipython-genutils                      0.2.0
# ipython-sql                           0.5.0
# ipywidgets                            7.7.1
# isoduration                           20.11.0
# itsdangerous                          2.2.0
# jaraco.classes                        3.4.0
# jaraco.context                        6.1.2
# jaraco.functools                      4.5.0
# jax                                   0.7.2
# jax-cuda12-pjrt                       0.7.2
# jax-cuda12-plugin                     0.7.2
# jaxlib                                0.7.2
# jeepney                               0.9.0
# jieba                                 0.42.1
# Jinja2                                3.1.6
# jiter                                 0.16.0
# joblib                                1.5.3
# joserfc                               1.7.3
# jsonpatch                             1.33
# jsonpickle                            4.1.2
# jsonpointer                           3.1.1
# jsonschema                            4.26.0
# jsonschema-specifications             2025.9.1
# jupyter_client                        7.4.9
# jupyter-console                       6.6.3
# jupyter_core                          5.9.1
# jupyter-events                        0.12.1
# jupyter_kernel_gateway                2.5.2
# jupyter-leaflet                       0.20.0
# jupyter_server                        2.20.0
# jupyter_server_terminals              0.5.4
# jupyterlab_pygments                   0.3.0
# jupyterlab_widgets                    3.0.16
# jupytext                              1.19.4
# kaggle                                2.0.2
# kagglehub                             1.0.2
# kagglesdk                             0.1.23
# keras                                 3.13.2
# keras-hub                             0.26.0
# keras-nlp                             0.26.0
# keyring                               25.7.0
# keyrings.google-artifactregistry-auth 1.1.2
# kiwisolver                            1.5.0
# langchain                             1.3.13
# langchain-core                        1.4.9
# langchain-protocol                    0.0.18
# langgraph                             1.2.9
# langgraph-checkpoint                  4.1.1
# langgraph-prebuilt                    1.1.0
# langgraph-sdk                         0.4.2
# langsmith                             0.10.2
# lark                                  1.3.1
# launchpadlib                          1.10.16
# lazr.restfulclient                    0.14.4
# lazr.uri                              1.0.6
# lazy-loader                           0.5
# libclang                              18.1.1
# libcudf-cu12                          26.2.1
# libcugraph-cu12                       26.2.0
# libcuml-cu12                          26.2.0
# libcuvs-cu12                          26.2.0
# libkvikio-cu12                        26.2.0
# libpysal                              4.14.1
# libraft-cu12                          26.2.0
# librmm-cu12                           26.2.0
# librosa                               0.11.0
# libucx-cu12                           1.19.0
# libucxx-cu12                          0.48.0
# lightgbm                              4.6.0
# linkify-it-py                         2.1.0
# llvmlite                              0.43.0
# locket                                1.0.0
# logical-unification                   0.4.7
# lxml                                  6.1.1
# Mako                                  1.1.3
# mapclassify                           2.10.0
# Markdown                              3.10.2
# markdown-it-py                        4.2.0
# MarkupSafe                            3.0.3
# matplotlib                            3.10.0
# matplotlib-inline                     0.2.2
# matplotlib-venn                       1.1.2
# mdit-py-plugins                       0.6.1
# mdurl                                 0.1.2
# mgwr                                  2.2.1
# miniKanren                            1.0.5
# missingno                             0.5.2
# mistune                               3.3.3
# mizani                                0.13.5
# mkl                                   2025.3.1
# ml_dtypes                             0.5.4
# mlxtend                               0.23.4
# mmh3                                  5.2.1
# momepy                                0.11.0
# more-itertools                        10.8.0
# moviepy                               1.0.3
# mpmath                                1.3.0
# msgpack                               1.2.1
# multidict                             6.7.1
# multipledispatch                      1.0.0
# multiprocess                          0.70.16
# multitasking                          0.0.13
# murmurhash                            1.0.15
# music21                               9.9.2
# namex                                 0.1.0
# narwhals                              2.24.0
# natsort                               8.4.0
# nbclassic                             1.3.3
# nbclient                              0.10.4
# nbconvert                             7.17.1
# nbformat                              5.10.4
# ndindex                               1.10.1
# nest-asyncio                          1.6.0
# networkx                              3.6.1
# nh3                                   0.3.6
# nibabel                               5.4.2
# nltk                                  3.9.1
# notebook                              6.5.7
# notebook_shim                         0.2.4
# numba                                 0.60.0
# numba-cuda                            0.22.2
# numexpr                               2.14.1
# numpy                                 2.0.2
# nvidia-cublas-cu12                    12.8.4.1
# nvidia-cuda-cccl-cu12                 12.9.27
# nvidia-cuda-cupti-cu12                12.8.90
# nvidia-cuda-nvcc-cu12                 12.8.93
# nvidia-cuda-nvrtc-cu12                12.8.93
# nvidia-cuda-runtime-cu12              12.8.90
# nvidia-cudnn-cu12                     9.19.0.56
# nvidia-cufft-cu12                     11.3.3.83
# nvidia-cufile-cu12                    1.13.1.3
# nvidia-curand-cu12                    10.3.9.90
# nvidia-cusolver-cu12                  11.7.3.90
# nvidia-cusparse-cu12                  12.5.8.93
# nvidia-cusparselt-cu12                0.7.1
# nvidia-libnvcomp-cu12                 5.1.0.21
# nvidia-ml-py                          13.610.43
# nvidia-nccl-cu12                      2.28.9
# nvidia-nvimgcodec-cu12                0.7.0.11
# nvidia-nvjitlink-cu12                 12.8.93
# nvidia-nvshmem-cu12                   3.4.5
# nvidia-nvtx-cu12                      12.8.90
# nvtx                                  0.2.15
# nx-cugraph-cu12                       26.2.0
# oauth2client                          4.1.3
# oauthlib                              3.3.1
# omegaconf                             2.3.1
# onemkl-license                        2025.3.1
# openai                                2.45.0
# opencv-contrib-python                 4.13.0.92
# opencv-python                         5.0.0.93
# opencv-python-headless                5.0.0.93
# openpyxl                              3.1.5
# opentelemetry-api                     1.42.1
# opentelemetry-resourcedetector-gcp    1.12.0a0
# opentelemetry-sdk                     1.42.1
# opentelemetry-semantic-conventions    0.63b1
# opt_einsum                            3.4.0
# optax                                 0.2.8
# optree                                0.19.1
# orbax-checkpoint                      0.12.1
# orjson                                3.11.9
# ormsgpack                             1.12.2
# osqp                                  1.1.3
# packaging                             26.2
# pandas                                2.2.2
# pandas-datareader                     0.11.1
# pandas-gbq                            0.30.0
# pandas-stubs                          2.2.2.240909
# pandocfilters                         1.5.1
# panel                                 1.9.3
# panel-material-ui                     0.14.0
# param                                 2.4.1
# parso                                 0.8.7
# parsy                                 2.2
# partd                                 1.4.2
# patsy                                 1.0.2
# peewee                                4.2.2
# peft                                  0.19.1
# pexpect                               4.9.0
# pickleshare                           0.7.5
# pillow                                11.3.0
# pip                                   24.1.2
# platformdirs                          4.10.0
# plotly                                5.24.1
# plotnine                              0.14.5
# pluggy                                1.6.0
# plum-dispatch                         2.9.0
# pointpats                             2.5.5
# polars                                1.35.2
# polars-runtime-32                     1.35.2
# pooch                                 1.9.0
# portpicker                            1.5.2
# preshed                               3.0.13
# prettytable                           3.18.0
# proglog                               0.1.12
# progressbar2                          4.5.0
# prometheus_client                     0.25.0
# promise                               2.3
# prompt_toolkit                        3.0.52
# propcache                             0.5.2
# prophet                               1.3.0
# proto-plus                            1.28.1
# protobuf                              5.29.6
# psutil                                5.9.5
# psycopg2                              2.9.12
# psygnal                               0.15.1
# ptyprocess                            0.7.0
# PuLP                                  3.3.2
# py-cpuinfo                            9.0.0
# py4j                                  0.10.9.9
# pyarrow                               18.1.0
# pyasn1                                0.6.4
# pyasn1_modules                        0.4.2
# pycairo                               1.29.0
# pycocotools                           2.0.11
# pycparser                             3.0
# pycryptodomex                         3.23.0
# pydantic                              2.13.4
# pydantic_core                         2.46.4
# pydata-google-auth                    1.9.1
# pydot                                 4.0.1
# pydotplus                             2.0.2
# PyDrive2                              1.21.1
# pydub                                 0.25.1
# pyerfa                                2.0.1.5
# pygame                                2.6.1
# pygit2                                1.19.3
# Pygments                              2.20.0
# PyGObject                             3.48.2
# pyiceberg                             0.11.1
# PyJWT                                 2.13.0
# pylibcudf-cu12                        26.2.1
# pylibcugraph-cu12                     26.2.0
# pylibraft-cu12                        26.2.0
# pymc                                  5.28.5
# pynndescent                           0.6.0
# pyogrio                               0.13.0
# pyomo                                 6.10.1
# PyOpenGL                              3.1.10
# pyOpenSSL                             26.3.0
# pyparsing                             3.3.2
# pyperclip                             1.11.0
# pyproj                                3.7.2
# pyroaring                             1.1.0
# pysal                                 25.7
# pyshp                                 3.1.4
# PySocks                               1.7.1
# pyspark                               4.0.3
# pytensor                              2.38.3
# pytest                                8.4.2
# python-apt                            0.0.0
# python-box                            7.4.1
# python-dateutil                       2.9.0.post0
# python-dotenv                         1.2.2
# python-fasthtml                       0.14.6
# python-json-logger                    4.1.0
# python-louvain                        0.16
# python-multipart                      0.0.32
# python-slugify                        8.0.4
# python-snappy                         0.7.3
# python-utils                          4.0.0
# pytz                                  2025.2
# pyviz_comms                           3.0.6
# PyWavelets                            1.9.0
# PyYAML                                6.0.3
# pyzmq                                 26.2.1
# quantecon                             0.11.3
# raft-dask-cu12                        26.2.0
# rapids-dask-dependency                26.2.0
# rapids-logger                         0.2.3
# rasterio                              1.5.0
# rasterstats                           0.21.0
# ratelim                               0.1.6
# referencing                           0.37.0
# regex                                 2025.11.3
# requests                              2.32.4
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# requirements-parser                   0.9.0
# rfc3339-validator                     0.1.4
# rfc3986-validator                     0.1.1
# rfc3987-syntax                        1.1.0
# rich                                  13.9.4
# rmm-cu12                              26.2.0
# roman-numerals                        4.1.0
# roman-numerals-py                     4.1.0
# rpds-py                               2026.6.3
# rpy2                                  3.5.17
# rsa                                   4.9.1
# rtree                                 1.4.1
# safehttpx                             0.1.7
# safetensors                           0.8.0
# scikit-image                          0.25.2
# scikit-learn                          1.6.1
# scipy                                 1.16.3
# scooby                                0.11.2
# scs                                   3.2.11
# seaborn                               0.13.2
# SecretStorage                         3.5.0
# segregation                           2.5.4
# semantic-version                      2.10.0
# Send2Trash                            2.1.0
# sentence-transformers                 5.6.0
# sentencepiece                         0.2.2
# sentry-sdk                            2.65.0
# setuptools                            75.2.0
# shap                                  0.52.0
# shapely                               2.1.2
# shellingham                           1.5.4
# simple-parsing                        0.1.8
# simplejson                            4.1.1
# simsimd                               6.5.16
# six                                   1.17.0
# sklearn-compat                        0.1.6
# sklearn-pandas                        2.2.0
# slicer                                0.0.8
# smart_open                            8.0.0
# smmap                                 5.0.3
# sniffio                               1.3.1
# snowballstemmer                       3.1.1
# sortedcontainers                      2.4.0
# soundfile                             0.14.0
# soupsieve                             2.8.4
# soxr                                  1.1.0
# spacy                                 3.8.14
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# spaghetti                             1.7.6
# spanner-graph-notebook                1.1.10
# spglm                                 1.1.0
# Sphinx                                8.2.3
# sphinxcontrib-applehelp               2.0.0
# sphinxcontrib-devhelp                 2.0.0
# sphinxcontrib-htmlhelp                2.1.0
# sphinxcontrib-jsmath                  1.0.1
# sphinxcontrib-qthelp                  2.0.0
# sphinxcontrib-serializinghtml         2.0.0
# spint                                 1.1.0
# splot                                 1.1.7
# spopt                                 0.7.0
# spreg                                 1.9.0
# SQLAlchemy                            2.0.51
# sqlglot                               25.20.2
# sqlparse                              0.5.5
# srsly                                 2.5.3
# stanio                                0.5.1
# starlette                             1.3.1
# statsmodels                           0.14.6
# strictyaml                            1.7.3
# stringzilla                           4.6.2
# stumpy                                1.13.0
# sympy                                 1.14.0
# tables                                3.10.2
# tabulate                              0.9.0
# tbb                                   2022.3.1
# tblib                                 3.2.2
# tcmlib                                1.5.0
# tenacity                              9.1.4
# tensorboard                           2.20.0
# tensorboard-data-server               0.7.2
# tensorflow                            2.20.0
# tensorflow-datasets                   4.9.10
# tensorflow-hub                        0.16.1
# tensorflow-metadata                   1.21.0
# tensorflow-probability                0.25.0
# tensorflow-text                       2.20.1
# tensorstore                           0.1.84
# termcolor                             3.3.0
# terminado                             0.18.1
# text-unidecode                        1.3
# textblob                              0.19.0
# tf_keras                              2.20.0
# tf-slim                               1.1.0
# thinc                                 8.3.13
# threadpoolctl                         3.6.0
# tifffile                              2026.4.11
# tiktoken                              0.13.0
# timm                                  1.0.28
# tinycss2                              1.5.1
# tobler                                0.14.0
# tokenizers                            0.22.2
# toml                                  0.10.2
# tomlkit                               0.14.0
# toolz                                 0.12.1
# torch                                 2.11.0+cu128
# torchao                               0.10.0
# torchaudio                            2.11.0+cu128
# torchcodec                            0.11.0+cu128
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.26.0+cu128
# tornado                               6.5.7
# tqdm                                  4.67.3
# traitlets                             5.7.1
# traittypes                            0.2.3
# transformers                          5.13.1
# treelite                              4.7.0
# treescope                             0.1.10
# triton                                3.6.0
# truststore                            0.10.4
# tsfresh                               0.21.2
# tweepy                                4.17.0
# typeguard                             4.5.2
# typer                                 0.26.8
# types-pytz                            2026.2.0.20260518
# types-setuptools                      82.0.0.20260518
# typing_extensions                     4.16.0
# typing-inspection                     0.4.2
# tzdata                                2026.3
# tzlocal                               5.4.4
# uc-micro-py                           2.0.0
# ucxx-cu12                             0.48.0
# umap-learn                            0.5.12
# umf                                   1.0.3
# uri-template                          1.3.0
# uritemplate                           4.2.0
# urllib3                               2.5.0
# uuid_utils                            0.17.0
# uvicorn                               0.51.0
# uvloop                                0.22.1
# vega-datasets                         0.9.0
# wadllib                               1.3.6
# wandb                                 0.28.0
# wasabi                                1.1.3
# watchdog                              6.0.0
# watchfiles                            1.2.0
# wcwidth                               0.8.2
# weasel                                1.0.0
# webcolors                             25.10.0
# webencodings                          0.5.1
# websocket-client                      1.9.0
# websockets                            15.0.1
# Werkzeug                              3.1.8
# wheel                                 0.47.0
# widgetsnbextension                    3.6.10
# wordcloud                             1.9.6
# wrapt                                 2.2.2
# xarray                                2025.12.0
# xarray-einstats                       0.10.0
# xgboost                               3.3.0
# xlrd                                  2.0.2
# xxhash                                3.8.1
# xyzservices                           2026.3.0
# yarl                                  1.24.2
# ydf                                   0.15.0
# ydf_tf                                2.20.0
# yellowbrick                           1.5
# yfinance                              0.2.66
# zict                                  3.0.0
# zipp                                  4.1.0
# zstandard                             0.25.0

# %% [markdown]
# And other softwares/libraries on the google colab linux are:

# %%
# !apt list | wc -l
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# 144892

# %% [markdown]
# Think well before you run the next command to see all the packages.
# (I recommend you to add "| head" or "| grep python", etc.)

# %%
# !apt list
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# spf-tools-perl/jammy 2.9.0-5 all
# spf-tools-python/jammy 2.0.14-2 all
# spfquery/jammy 1.2.10-7.1ubuntu1 amd64
# sphde-utils/jammy 1.4.0-2build1 amd64
# sphinx-common/jammy 4.3.2-1 all
# sphinx-doc/jammy 4.3.2-1 all
# sphinx-intl/jammy 2.0.1-2 amd64
# sphinx-rtd-theme-common/jammy 1.0.0+dfsg-1 all
# sphinx-voxforge-hmm-en/jammy 0.1.1~daily20130301-0ubuntu1 all
# sphinx-voxforge-lm-en/jammy 0.1.1~daily20130301-0ubuntu1 all
# sphinxbase-utils/jammy 0.8+5prealpha+1-13build1 amd64
# sphinxsearch/jammy 2.2.11-8 amd64
# sphinxtrain/jammy 1.0.8+5prealpha+1-4 amd64
# spi-tools/jammy 0.8.4-1 amd64
# spice-client-glib-usb-acl-helper/jammy 0.39-3ubuntu1 amd64
# spice-client-gtk/jammy 0.39-3ubuntu1 amd64
# spice-html5/jammy 0.2.2-0ubuntu3 all
# spice-vdagent/jammy 0.22.1-1 amd64
# spice-webdavd/jammy 2.5-1 amd64
# spigot/jammy 0.2017-01-15.gdad1bbc6-1build2 amd64
# spim/jammy 8.0+dfsg-6.1 amd64
# spin/jammy 6.5.2+dfsg-1 amd64
# spinner/jammy 1.2.4-6 amd64
# spip/jammy 4.0.4-1 all
# spiped/jammy 1.6.2-1 amd64
# spirv-cross/jammy 2021.01.15-5 amd64
# spirv-headers/jammy-updates,jammy-security 1.6.1+1.3.216.0-1~ubuntu0.22.04.2 all
# spirv-tools/jammy 2022.1+1.3.204.0-2 amd64
# splash/jammy 3.3.4-1 amd64
# splat/jammy 1.4.2-3build1 amd64
# splay/jammy 0.9.5.2-14build1 amd64
# spline/jammy 1.2-5 amd64
# splint-data/jammy 1:3.1.2+dfsg-5 all
# splint-doc-html/jammy 1:3.1.2+dfsg-5 all
# splint/jammy 1:3.1.2+dfsg-5 amd64
# split-select/jammy 1:10.0.0+r36-3 amd64
# splitpatch/jammy 1.0+20190128+git3b2edf2-3 all
# splitvt/jammy 1.6.6-13build2 amd64
# spoa/jammy 4.0.7+ds-2 amd64
# spooles-doc/jammy 2.2-14 all
# spotlighter/jammy 0.3-1.1build1 amd64
# spout/jammy 1.4-4 amd64
# sprai/jammy 0.9.9.23+dfsg1-2 amd64
# spread-phy/jammy 1.0.7+dfsg-4 all
# spring-common/jammy 105.0.1+dfsg-4 all
# spring-javaai/jammy 105.0.1+dfsg-4 all
# spring-maps-kernelpanic/jammy 4.1-0ubuntu1 all
# spring-mods-kernelpanic/jammy 4.1-0ubuntu1 all
# spring/jammy 105.0.1+dfsg-4 amd64
# springlobby/jammy 0.273-1build2 amd64
# sptk/jammy 3.9-3 amd64
# sputnik/jammy 12.06.27-2.1 all
# spview/jammy 2.0.0~beta2-2 all
# spyder-common/jammy 4.2.1+dfsg1-3 all
# spyder3/jammy 4.2.1+dfsg1-3 all
# spyder/jammy 4.2.1+dfsg1-3 all
# sq-keyring-linter/jammy-updates,jammy-security 0.5.0-1ubuntu0.22.04.1 amd64
# sq/jammy-updates,jammy-security 0.25.0-3ubuntu0.22.04.1 amd64
# sqitch/jammy 1.2.1-1 all
# sql-migrate/jammy 0.0~git20191213.0633851-2build1 amd64
# sqlacodegen/jammy 1.1.6-4 all
# sqlcipher/jammy 3.4.1-2build1 amd64
# sqlcl-package/jammy 0.1.1 all
# sqldeveloper-package/jammy 0.5.4 all
# sqlformat/jammy-updates,jammy-security 0.4.2-1ubuntu0.22.04.2 all
# sqlgrey/jammy 1:1.8.0-4 all
# sqlite-doc/jammy 2.8.17-15fakesync1build1 all
# sqlite3-doc/jammy-updates,jammy-security 3.37.2-2ubuntu0.5 all
# sqlite3-pcre/jammy 0~git20070120091816+4229ecc-2 amd64
# sqlite3-tools/jammy-updates,jammy-security 3.37.2-2ubuntu0.5 amd64
# sqlite3/jammy-updates,jammy-security 3.37.2-2ubuntu0.5 amd64
# sqlite/jammy 2.8.17-15fakesync1build1 amd64
# sqlitebrowser/jammy 3.12.1-2 amd64
# sqlline/jammy 1.0.2-8 all
# sqlmap/jammy 1.6.4-2 all
# sqlobject-admin/jammy 3.9.1+dfsg-1 all
# sqlsmith/jammy 1.3-1build1 amd64
# sqop/jammy-updates,jammy-security 0.26.1-2ubuntu0.22.04.1 amd64
# sqsh/jammy 2.5.16.1-2build2 amd64
# squareness/jammy 2.3.0-7 all
# squashfs-tools-ng/jammy 1.1.3-2 amd64
# squashfs-tools/jammy 1:4.5-3build1 amd64
# squashfuse/jammy 0.1.103-3 amd64
# squeak-plugins-scratch-dbg/jammy 1.4.0.2~svn.r83-3 amd64
# squeak-plugins-scratch/jammy 1.4.0.2~svn.r83-3 amd64
# squeak-vm/jammy 1:4.10.2.2614+20120917~dfsg-1 amd64
# squeekboard-devel/jammy 1.17.1-0ubuntu1 amd64
# squeekboard/jammy 1.17.1-0ubuntu1 amd64
# squeezelite-pa/jammy 1.9.9-1395+git20220104.874e4f9-1 amd64
# squeezelite-pulseaudio/jammy 1.9.9-1395+git20220104.874e4f9-1 amd64
# squeezelite/jammy 1.9.9-1395+git20220104.874e4f9-1 amd64
# squid-cgi/jammy-updates,jammy-security 5.9-0ubuntu0.22.04.5 amd64
# squid-common/jammy-updates,jammy-security 5.9-0ubuntu0.22.04.5 all
# squid-deb-proxy-client/jammy 0.8.15+nmu1ubuntu1 all
# squid-deb-proxy/jammy 0.8.15+nmu1ubuntu1 all
# squid-langpack/jammy 20200403-1 all
# squid-openssl/jammy-updates,jammy-security 5.9-0ubuntu0.22.04.5 amd64
# squid-purge/jammy-updates,jammy-security 5.9-0ubuntu0.22.04.5 amd64
# squid/jammy-updates,jammy-security 5.9-0ubuntu0.22.04.5 amd64
# squidclient/jammy-updates,jammy-security 5.9-0ubuntu0.22.04.5 amd64
# squidguard-doc/jammy 1.6.0-2build1 all
# squidguard/jammy 1.6.0-2build1 amd64
# squidtaild/jammy 2.1a6-6.1 all
# squidview/jammy 0.86-1build2 amd64
# squirrel3/jammy 3.1-8build1 amd64
# squishyball/jammy 0.1~svn19085-5build1 amd64
# squizz/jammy 0.99d+dfsg-3 amd64
# sqv/jammy 1.1.0-1 amd64
# sqwebmail-de/jammy 6.0.0-1 all
# sqwebmail/jammy 6.0.5+1.0.16-3build3 amd64
# sra-toolkit/jammy 2.11.3+dfsg-1ubuntu1 amd64
# srain/jammy 1.3.2-1 amd64
# src2tex/jammy 2.12h-9 amd64
# srecord/jammy 1.64-3 amd64
# sredird/jammy 2.2.1-2build1 amd64
# sreview-common/jammy 0.8.0-1 all
# sreview-detect/jammy 0.8.0-1 all
# sreview-encoder/jammy 0.8.0-1 all
# sreview-master/jammy 0.8.0-1 all
# sreview-web/jammy 0.8.0-1 all
# srf-doc/jammy 0.1+dfsg-7 all
# srm-ifce-dev/jammy 1.24.5-1build1 amd64
# srptools/jammy 39.0-1 amd64
# srs/jammy 0.31-6 all
# srst2/jammy 0.2.0-9 amd64
# srt-tools/jammy 1.4.4-4 amd64
# ss-dev/jammy-updates 2.0-1.46.5-2ubuntu1.2 amd64
# ssake-examples/jammy 4.0.1-1 all
# ssake/jammy 4.0.1-1 all
# sscg/jammy 3.0.2-1 amd64
# ssdeep/jammy 2.14.1+git20180629.57fcfff-2 amd64
# sse3-support/jammy 6 amd64
# sse4.2-support/jammy 6 amd64
# ssed/jammy 3.62-8 amd64
# ssft/jammy 0.9.17+nmu1 all
# ssh-agent-filter/jammy 0.5.2-1build4 amd64
# ssh-askpass-fullscreen/jammy 0.3-3.1build2 amd64
# ssh-askpass-gnome/jammy-updates,jammy-security 1:8.9p1-3ubuntu0.15 amd64
# ssh-askpass/jammy 1:1.2.4.1-13 amd64
# ssh-audit/jammy 2.5.0-1 all
# ssh-contact-client/jammy 0.7-1.1 amd64
# ssh-contact-service/jammy 0.7-1.1 amd64
# ssh-contact/jammy 0.7-1.1 all
# ssh-cron/jammy 1.03.00-1 amd64
# ssh-import-id/jammy 5.11-0ubuntu1 all
# ssh-tools/jammy 1.7-2 all
# ssh/jammy-updates,jammy-security 1:8.9p1-3ubuntu0.15 all
# sshcommand/jammy 0~20160110.1~2795f65-1.1 all
# sshesame/jammy-updates,jammy-security 0.0~git20210926.d7fdb81-1ubuntu0.22.04.1 amd64
# sshfs/jammy 3.7.1+repack-2 amd64
# sshguard/jammy 2.4.2-1 amd64
# sshoot/jammy 1.4.2-2 all
# sshpass/jammy 1.09-1 amd64
# sshuttle/jammy 1.0.5-1ubuntu4 all
# ssl-cert-check/jammy 4.14-1 all
# ssl-cert/jammy 1.1.2 all
# ssldump/jammy 1.3-2build1 amd64
# sslh/jammy-updates,jammy-security 1.20-1+deb11u1build0.22.04.1 amd64
# sslscan/jammy 2.0.7-1build1 amd64
# sslsniff/jammy 0.8-9ubuntu2 amd64
# sslsplit/jammy 0.5.5-2 amd64
# ssmping/jammy 0.9.1-4 amd64
# ssmtp/jammy 2.64-10 amd64
# ssocr/jammy 2.22.1-1 amd64
# sspace/jammy 2.1.1+dfsg-6 all
# sssd-ad-common/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-ad/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-common/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-dbus/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-ipa/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-kcm/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-krb5-common/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-krb5/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-ldap/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-proxy/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd-tools/jammy-updates 2.6.3-1ubuntu3.6 amd64
# sssd/jammy-updates 2.6.3-1ubuntu3.6 amd64
# ssshtest/jammy 0.0+git20190416.6f5438a-2 all
# ssss/jammy 0.5-5 amd64
# sstp-client/jammy 1.0.17-1 amd64
# ssvnc/jammy 1.0.29-6 amd64
# ssw-align/jammy 1.1-13 amd64
# st-console/jammy 1.1.4-6 all
# stac-client/jammy 0.7.5-1~jammy1 all
# stac-validator/jammy 3.3.2+ds-2~jammy0 all
# stacer/jammy 1.1.0+ds-1 amd64
# stacks/jammy 2.60+dfsg-1 amd64
# staden-common/jammy 2.0.0+b11-4build2 all
# staden-io-lib-examples/jammy 1.14.14+dfsg-1 all
# staden-io-lib-utils/jammy 1.14.14+dfsg-1 amd64
# staden/jammy 2.0.0+b11-4build2 amd64
# stalin/jammy 0.11-6build2 amd64
# stalonetray/jammy 0.8.1-1build1 amd64
# standardskriver/jammy 0.0.4-1 all
# stardata-common/jammy 0.8build1 amd64
# stardict-common/jammy 3.0.7+git20211225+dfsg-1 all
# stardict-czech/jammy 20171101-1 all
# stardict-english-czech/jammy 20171101-1 all
# stardict-german-czech/jammy 20171101-1 all
# stardict-gtk/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-plugin-cal/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-plugin-espeak/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-plugin-festival/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-plugin-fortune/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-plugin-info/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-plugin-spell/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-plugin/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-tools/jammy 3.0.7+git20211225+dfsg-1 amd64
# stardict-xmlittre/jammy 1:1.0-2 all
# stardict/jammy 3.0.7+git20211225+dfsg-1 all
# starfighter-data/jammy 2.3.3-1 all
# starfighter/jammy 2.3.3-1 amd64
# starlet/jammy 0.31-1.1 all
# starlink-array-java-doc/jammy 0.2+2020.10.01-1 all
# starlink-array-java/jammy 0.2+2020.10.01-1 all
# starlink-cdf-java-doc/jammy 1.0+2021.12.15+dfsg-1 all
# starlink-cdf-java/jammy 1.0+2021.12.15+dfsg-1 all
# starlink-connect-java-doc/jammy 0.1+2020.10.01-1 all
# starlink-connect-java/jammy 0.1+2020.10.01-1 all
# starlink-datanode-java-doc/jammy 1.0+2020.10.01-1 all
# starlink-datanode-java/jammy 1.0+2020.10.01-1 all
# starlink-dpac-java-doc/jammy 1.0+2021.01.08-1 all
# starlink-dpac-java/jammy 1.0+2021.01.08-1 all
# starlink-ecsv-java-doc/jammy 1.0+2021.08.26-1 all
# starlink-ecsv-java/jammy 1.0+2021.08.26-1 all
# starlink-fits-java-doc/jammy 0.1+2021.09.03-1 all
# starlink-fits-java/jammy 0.1+2021.09.03-1 all
# starlink-pal-java-doc/jammy 1.0.1+2020.10.01-1 all
# starlink-pal-java/jammy 1.0.1+2020.10.01-1 all
# starlink-registry-java-doc/jammy 1.2+2020.10.01-1 all
# starlink-registry-java/jammy 1.2+2020.10.01-1 all
# starlink-table-java-doc/jammy 4.0.5-1 all
# starlink-table-java/jammy 4.0.5-1 all
# starlink-task-java-doc/jammy 0.2+2022.01.10-1 all
# starlink-task-java/jammy 0.2+2022.01.10-1 all
# starlink-tjoin-java-doc/jammy 1.0+2021.09.09-1 all
# starlink-tjoin-java/jammy 1.0+2021.09.09-1 all
# starlink-topcat-java-doc/jammy 4.8.3-1 all
# starlink-topcat-java/jammy 4.8.3-1 all
# starlink-ttools-java-doc/jammy 3.4.3-1 all
# starlink-ttools-java/jammy 3.4.3-1 all
# starlink-util-java-doc/jammy 1.0+2021.09.10-1 all
# starlink-util-java/jammy 1.0+2021.09.10-1 all
# starlink-vo-java-doc/jammy 0.2+2022.01.20-1 all
# starlink-vo-java/jammy 0.2+2022.01.20-1 all
# starlink-votable-java-doc/jammy 2.0+2022.01.28-1 all
# starlink-votable-java/jammy 2.0+2022.01.28-1 all
# starman/jammy 0.4015-1 all
# starplot/jammy 0.95.5-8.3build2 amd64
# starpu-contrib-examples/jammy 1.3.9+dfsg-1 amd64
# starpu-contrib-tools/jammy 1.3.9+dfsg-1 amd64
# starpu-examples/jammy 1.3.9+dfsg-1 amd64
# starpu-tools/jammy 1.3.9+dfsg-1 amd64
# starvoyager-data/jammy 0.4.4-10 all
# starvoyager/jammy 0.4.4-10 amd64
# statcvs/jammy 1:0.7.0.dfsg-7 all
# statgrab/jammy 0.92.1-1build1 amd64
# staticsite/jammy 1.4.1-1 all
# statnews/jammy 2.6 all
# statserial/jammy 1.1-25 amd64
# statsprocessor/jammy 0.11+git20160316-3 amd64
# statsvn/jammy 0.7.0.dfsg-10 all
# stax/jammy 1.37-2 amd64
# stayrtr/jammy-updates,jammy-security 0.3.0-1ubuntu0.1 amd64
# stda/jammy 1.3.1-2.1 all
# stdsyslog/jammy 0.03.3-4 amd64
# ste-plugins/jammy 0.0.2-6build1 amd64
# stealth-doc/jammy 4.03.01-1 all
# stealth/jammy 4.03.01-1 amd64
# steam-devices/jammy 1:1.0.0.74-1ubuntu2 all
# steam-installer/jammy 1.0.0.74-1ubuntu2 all
# stegcracker/jammy 2.1.0-2 all
# steghide-doc/jammy 0.5.1-15 all
# steghide/jammy 0.5.1-15 amd64
# stegosuite/jammy 0.8.0-2 all
# stegsnow/jammy 20130616-6 amd64
# stella/jammy 6.6-1 amd64
# stellarium-data/jammy 0.20.4-3 all
# stellarium/jammy 0.20.4-3 amd64
# stenc/jammy 1.0.7-2build1 amd64
# stenographer-client/jammy-updates,jammy-security 1.0.1-2ubuntu0.22.04.3 all
# stenographer-common/jammy-updates,jammy-security 1.0.1-2ubuntu0.22.04.3 all
# stenographer/jammy-updates,jammy-security 1.0.1-2ubuntu0.22.04.3 amd64
# step/jammy 4:21.12.3-0ubuntu1 amd64
# stepic/jammy 0.5.0-1 all
# steptalk/jammy 0.10.0-6build9 amd64
# stetl/jammy 2.0+ds-3 all
# stex/jammy 1.2.1+git20171204.g5e4f0ca-4 all
# stgit-contrib/jammy 0.19-1 all
# stgit/jammy 0.19-1 all
# stiff/jammy 2.4.0-6 amd64
# stilts-doc/jammy 3.4.3-1 all
# stilts/jammy 3.4.3-1 all
# stilview/jammy 2.2.3-1 amd64
# stimfit-dbg/jammy 0.16.0-1ubuntu1 amd64
# stimfit/jammy 0.16.0-1ubuntu1 amd64
# stk-doc/jammy 4.6.1+dfsg-3build2 all
# stk/jammy 4.6.1+dfsg-3build2 amd64
# stl-manual/jammy 3.30-17 all
# stlcmd/jammy 1.1-1build1 amd64
# stlink-gui/jammy 1.7.0+ds-1 amd64
# stlink-tools/jammy 1.7.0+ds-1 amd64
# stm32flash/jammy 0.5+git20200914+2b0f078-1 amd64
# stockfish/jammy 14.1-1 amd64
# stoken/jammy 0.92-1 amd64
# stompserver/jammy 0.9.9gem-4.1 all
# stone/jammy 2.4-1build1 amd64
# stopmotion/jammy 0.8.5-4 amd64
# stops/jammy 0.3.0-3 all
# stopt-doc/jammy 4.2+dfsg1-3 all
# stopt-examples/jammy 4.2+dfsg1-3 all
# stopwatch/jammy 3.5-9 all
# storebackup/jammy 3.2.1-2 all
# storj/jammy 1.0.3-1.2 amd64
# storm-lang-crypto/jammy 0.5.10-1 amd64
# storm-lang-graphics/jammy 0.5.10-1 amd64
# storm-lang-layout/jammy 0.5.10-1 amd64
# storm-lang-presentation/jammy 0.5.10-1 amd64
# storm-lang-sound/jammy 0.5.10-1 amd64
# storm-lang-sql/jammy 0.5.10-1 amd64
# storm-lang-ui/jammy 0.5.10-1 amd64
# storm-lang/jammy 0.5.10-1 amd64
# stormbaancoureur-data/jammy 2.1.6-3 all
# stormbaancoureur/jammy 2.1.6-3 amd64
# storymaps/jammy 1.0+dfsg-3.1 all
# stow/jammy 2.3.1-1 all
# strace/jammy 5.16-0ubuntu3 amd64
# strcase-dev/jammy 0.1-3 all
# streamdeck-ui/jammy 1.1.2-2 all
# streamer/jammy 3.107-1.1 amd64
# streamlink/jammy 3.1.1-1 all
# streamripper/jammy 1.64.6-1build1 amd64
# streamtuner2/jammy 2.2.1+dfsg-2.1 all
# stress-ng/jammy-updates 0.13.12-2ubuntu1 amd64
# stress/jammy 1.0.5-1 amd64
# stressant-doc/jammy 0.6.0 all
# stressant-meta/jammy 0.6.0 all
# stressant/jammy 0.6.0 all
# stressapptest/jammy 1.0.6-2build2 amd64
# stretchplayer-dbg/jammy 0.503-4build1 amd64
# stretchplayer/jammy 0.503-4build1 amd64
# stringtie/jammy 2.2.1+ds-2 amd64
# strip-nondeterminism/jammy 1.13.0-1 all
# strongswan-charon/jammy-updates,jammy-security 5.9.5-2ubuntu2.6 amd64
# strongswan-libcharon/jammy-updates,jammy-security 5.9.5-2ubuntu2.6 amd64
# strongswan-nm/jammy-updates,jammy-security 5.9.5-2ubuntu2.6 amd64
# strongswan-pki/jammy-updates,jammy-security 5.9.5-2ubuntu2.6 amd64
# strongswan-scepclient/jammy-updates,jammy-security 5.9.5-2ubuntu2.6 amd64
# strongswan-starter/jammy-updates,jammy-security 5.9.5-2ubuntu2.6 amd64
# strongswan-swanctl/jammy-updates,jammy-security 5.9.5-2ubuntu2.6 amd64
# strongswan/jammy-updates,jammy-security 5.9.5-2ubuntu2.6 all
# structure-synth-dbg/jammy 1.5.0-7 amd64
# structure-synth/jammy 1.5.0-7 amd64
# stterm/jammy 0.8.4-1 amd64
# stubby/jammy 1.6.0-2build1 amd64
# studio-controls/jammy-updates 2.3.1-0ubuntu2 all
# stumpwm/jammy 2:1.0.0-1 all
# stun-client/jammy 0.97~dfsg-2.1build2 amd64
# stun-server/jammy 0.97~dfsg-2.1build2 amd64
# stunnel4/jammy 3:5.63-1build1 amd64
# stx2any/jammy 1.56-2.2 all
# stylish-haskell/jammy 0.12.2.0-1build1 amd64
# stymulator/jammy 0.21a~dfsg-2build2 amd64
# subdownloader/jammy 2.1.0-4 all
# subiquitycore/jammy 20.04.3+git84g6a5e36ed all
# sublime-music/jammy 0.11.16-3 all
# subliminal-nautilus/jammy 2.1.0-1 all
# subliminal/jammy 2.1.0-1 all
# submux-dvd/jammy 0.5.2-0ubuntu2 amd64
# subnetcalc/jammy 2.4.19-1 amd64
# subread-data/jammy 2.0.3+dfsg-1 all
# subread/jammy 2.0.3+dfsg-1 amd64
# substance-doc/jammy 7.3+dfsg3-5 all
# substance-flamingo-doc/jammy 7.3+dfsg3-5 all
# substance-flamingo/jammy 7.3+dfsg3-5 all
# substance-swingx-doc/jammy 7.3+dfsg3-5 all
# substance-swingx/jammy 7.3+dfsg3-5 all
# substance/jammy 7.3+dfsg3-5 all
# subtitlecomposer/jammy 0.7.1-2build2 amd64
# subtitleeditor/jammy 0.54.0-5 amd64
# subtle/jammy 0.11.3224-xi-2.2build4 amd64
# subunit/jammy 1.4.0-3 all
# subuser/jammy 0.6.2-3 all
# subversion-tools/jammy-updates,jammy-security 1.14.1-3ubuntu0.22.04.1 amd64
# subversion/jammy-updates,jammy-security 1.14.1-3ubuntu0.22.04.1 amd64
# suck/jammy 4.3.4-1build1 amd64
# suckless-tools/jammy 46-1 amd64
# sucrack/jammy 1.2.3-6 amd64
# sucrose/jammy 0.118-2 all
# sudo-ldap/jammy-updates,jammy-security 1.9.9-1ubuntu2.6 amd64
# sudo/jammy-updates,jammy-security,now 1.9.9-1ubuntu2.6 amd64 [installed]
# sudoku-solver/jammy 1.0.1-3 amd64
# sudoku/jammy 1.0.5-2build3 amd64
# suffixfsm/jammy-updates,jammy-security 0.0~git20150829.56e4718-5ubuntu0.22.04.1 amd64
# sugar-browse-activity/jammy 207-1 all
# sugar-calculate-activity/jammy 47-1 all
# sugar-chat-activity/jammy 86-3 all
# sugar-etoys-activity/jammy 116-10 all
# sugar-flipsticks-activity/jammy 1-0ubuntu2 all
# sugar-icon-theme/jammy 0.118-1 all
# sugar-imageviewer-activity/jammy 65-2 all
# sugar-jukebox-activity/jammy 36-2 all
# sugar-log-activity/jammy 42-2 all
# sugar-memorize-activity/jammy 58-3 all
# sugar-pippy-activity/jammy 75-2 all
# sugar-read-activity/jammy 123-2 all
# sugar-session/jammy 0.118-2 all
# sugar-sliderpuzzle-activity/jammy 5-0ubuntu2 all
# sugar-terminal-activity/jammy 47-2 all
# sugar-themes/jammy 0.118-1 all
# sugar-write-activity/jammy 101-2 all
# sugarplum/jammy 0.9.10-18.1 all
# suitename/jammy 0.4.130509+git20210223.ebb1325-1 amd64
# sumaclust/jammy 1.0.36+ds-1 amd64
# sumatra/jammy 1.0.36+ds-1 amd64
# sumo-doc/jammy 1.12.0+dfsg1-1 all
# sumo-tools/jammy 1.12.0+dfsg1-1 all
# sumo/jammy 1.12.0+dfsg1-1 amd64
# sumtrees/jammy 4.5.2-1 all
# sunclock-maps/jammy 3.57-11 all
# sunclock/jammy 3.57-11 amd64
# sunflow/jammy 0.07.2.svn396+dfsg-18 all
# sunpinyin-data/jammy 0.1.22+20170109-2 amd64
# sunpinyin-utils/jammy 3.0.0~rc2+ds1-4 amd64
# sunxi-tools/jammy 1.4.2+git20220212.08e209-1 amd64
# sup-mail/jammy 1.0-6 all
# sup/jammy 20100519-3 amd64
# super/jammy 3.30.3-2 amd64
# supercat/jammy 0.5.7-1 amd64
# supercollider-common/jammy 1:3.11.2+repack-1build1 all
# supercollider-dev/jammy 1:3.11.2+repack-1build1 amd64
# supercollider-emacs/jammy 1:3.11.2+repack-1build1 all
# supercollider-gedit/jammy 1:3.11.2+repack-1build1 all
# supercollider-ide/jammy 1:3.11.2+repack-1build1 amd64
# supercollider-language/jammy 1:3.11.2+repack-1build1 amd64
# supercollider-server/jammy 1:3.11.2+repack-1build1 amd64
# supercollider-supernova/jammy 1:3.11.2+repack-1build1 amd64
# supercollider-vim/jammy 1:3.11.2+repack-1build1 all
# supercollider/jammy 1:3.11.2+repack-1build1 amd64
# superkb/jammy 0.23-5 amd64
# supermin/jammy 5.2.1-4ubuntu2 amd64
# supertransball2-data/jammy 1.5-11 all
# supertransball2/jammy 1.5-11 amd64
# supertux-data/jammy 0.6.3-1 all
# supertux/jammy 0.6.3-1 amd64
# supertuxkart-data/jammy 1.3+dfsg1-3 all
# supertuxkart/jammy 1.3+dfsg1-3 amd64
# supervisor-doc/jammy 4.2.1-1ubuntu1 all
# supervisor/jammy 4.2.1-1ubuntu1 all
# supysonic/jammy 0.7.1+ds-1 all
# surankco/jammy 0.0.r5+dfsg-3 all
# surf-alggeo-doc/jammy 1.0.6+ds-6 all
# surf-alggeo-nox/jammy 1.0.6+ds-6 amd64
# surf-alggeo/jammy 1.0.6+ds-6 amd64
# surf-display/jammy 0.0.5-2 all
# surf/jammy-updates,jammy-security 2.1+git20210719-2ubuntu0.22.04.1 amd64
# surfraw-extra/jammy 2.3.0-0.3 all
# surfraw/jammy 2.3.0-0.3 all
# surgescript/jammy 0.5.4.4-1 amd64
# suricata-update/jammy 1.2.3-1 amd64
# suricata/jammy 1:6.0.4-3 amd64
# surpyvor/jammy 0.5-2 all
# suru-icon-theme/jammy 20.10-0ubuntu2 all
# survex-aven/jammy 1.4.1-1 amd64
# survex/jammy 1.4.1-1 amd64
# survivor/jammy 1.0.7-3 amd64
# susv2/jammy 7.20180621 all
# susv3/jammy 7.20180621 all
# susv4/jammy 7.20180621 all
# svdrpservice-dev/jammy 1.0.0-10 all
# svgpart/jammy 4:21.12.3-0ubuntu1 amd64
# svgtoipe/jammy 1:7.2.20-1ubuntu1 all
# svgtune/jammy 0.3.1-1 all
# sview/jammy 21.08.5-2ubuntu1 amd64
# svim/jammy 2.0.0-2 all
# svn-all-fast-export/jammy 1.0.18+git20200501-1 amd64
# svn-buildpackage/jammy 0.8.7 all
# svn-load/jammy 1.6-1 all
# svn2cl/jammy 0.14-2 all
# svn2git/jammy 2.4.0-3 all
# svnkit/jammy 1.10.3-1 all
# svt-av1/jammy 0.9.0+dfsg-1 amd64
# svtools/jammy 0.6-5 all
# svtplay-dl/jammy 3.0-2 all
# svxlink-calibration-tools/jammy 19.09.1-3 amd64
# svxlink-gpio/jammy 19.09.1-3 all
# svxlink-server/jammy 19.09.1-3 amd64
# svxreflector/jammy 19.09.1-3 amd64
# swac-get/jammy 0.5.1-0ubuntu4 amd64
# swac-scan/jammy 0.2-0ubuntu6 amd64
# swaks/jammy 20201014.0-2 all
# swami/jammy 2.2.2-1build1 amd64
# swapspace/jammy 1.17-1 amd64
# swarm/jammy 3.1.0+dfsg-1 amd64
# swarp/jammy 2.41.5-1 amd64
# swatch/jammy 3.2.4-4 all
# swath-data/jammy 0.6.1-2build1 all
# swath/jammy 0.6.1-2build1 amd64
# sway-backgrounds/jammy 1.7-1 all
# sway/jammy 1.7-1 amd64
# swaybg/jammy 1.0-2build1 amd64
# swayidle/jammy 1.7-1 amd64
# swayimg/jammy 1.6-2 amd64
# swaylock/jammy 1.5-2ubuntu1 amd64
# swe-basic-data/jammy 1.80.00.0002-1.1 all
# swe-standard-data/jammy 00004-1.1 all
# sweed/jammy 3.2.1+dfsg-5 amd64
# sweep-dev/jammy 0.9.3-9build1 all
# sweep/jammy 0.9.3-9build1 amd64
# sweeper/jammy 4:21.12.3-0ubuntu1 amd64
# sweethome3d-furniture-editor/jammy 1.28-1 all
# sweethome3d-furniture-nonfree/jammy 1.6.2-2 all
# sweethome3d-furniture/jammy 1.8-1 all
# sweethome3d-textures-editor/jammy 1.8-1 all
# sweethome3d/jammy 6.6.2+dfsg-1 all
# swell-foop/jammy 1:41.0.1-1 amd64
# swfmill/jammy 0.3.6-1build1 amd64
# swh-lv2/jammy 1.0.16+git20160519~repack0-3 amd64
# swh-plugins/jammy 0.4.17-2 amd64
# swi-prolog-bdb/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swi-prolog-core-packages/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swi-prolog-core/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swi-prolog-doc/jammy 8.4.2+dfsg-2ubuntu1 all
# swi-prolog-full/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swi-prolog-java/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swi-prolog-nox/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swi-prolog-odbc/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swi-prolog-test/jammy 8.4.2+dfsg-2ubuntu1 all
# swi-prolog-x/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swi-prolog/jammy 8.4.2+dfsg-2ubuntu1 amd64
# swift-account/jammy-updates,jammy-security 2.29.2-0ubuntu1.1 all
# swift-bench/jammy 1.2.0-5 all
# swift-container/jammy-updates,jammy-security 2.29.2-0ubuntu1.1 all
# swift-doc/jammy-updates,jammy-security 2.29.2-0ubuntu1.1 all
# swift-object-expirer/jammy-updates,jammy-security 2.29.2-0ubuntu1.1 all
# swift-object/jammy-updates,jammy-security 2.29.2-0ubuntu1.1 all
# swift-proxy/jammy-updates,jammy-security 2.29.2-0ubuntu1.1 all
# swift/jammy-updates,jammy-security 2.29.2-0ubuntu1.1 all
# swig-doc/jammy 4.0.2-1ubuntu1 all
# swig-examples/jammy 4.0.2-1ubuntu1 all
# swig-pocketsphinx/jammy 0.8.0+real5prealpha+1-14ubuntu1 all
# swig-sphinxbase/jammy 0.8+5prealpha+1-13build1 all
# swig3.0-doc/jammy 3.0.12-2.2ubuntu1 all
# swig3.0-examples/jammy 3.0.12-2.2ubuntu1 all
# swig3.0/jammy 3.0.12-2.2ubuntu1 amd64
# swig4.0-doc/jammy 4.0.2-1ubuntu1 all
# swig4.0-examples/jammy 4.0.2-1ubuntu1 all
# swig4.0/jammy 4.0.2-1ubuntu1 amd64
# swig/jammy 4.0.2-1ubuntu1 all
# swish++/jammy 6.1.5-6 amd64
# swish-e-dev/jammy 2.4.7-6.1build1 amd64
# swish-e/jammy 2.4.7-6.1build1 amd64
# swish/jammy 0.10.1.0-1 amd64
# swisswatch/jammy 0.6-19 amd64
# switchconf/jammy 0.0.17-1 all
# switcheroo-control/jammy 2.4-3build2 amd64
# switchsh/jammy 0~20070801-4 amd64
# sword-comm-mhcc/jammy 2.0-1 all
# sword-comm-scofield/jammy 1.0.1-4 all
# sword-comm-tdavid/jammy 2.0-1 all
# sword-dict-naves/jammy 3.0-1 all
# sword-dict-strongs-greek/jammy 3.0-2 all
# sword-dict-strongs-hebrew/jammy 3.0-1 all
# sword-text-arasvd/jammy 1.1-0ubuntu2 all
# sword-text-dutsvv/jammy 1.4-0ubuntu1 all
# sword-text-gerlut1545/jammy 1.2-0ubuntu2 all
# sword-text-kjv/jammy 5.3-1 all
# sword-text-sparv/jammy 2.28-1 all
# sword-text-swahili/jammy 1.1-0ubuntu1 all
# sword-text-tr/jammy 1.2-0ubuntu2 all
# sword-text-web/jammy 353.0-1 all
# sword-text-wlc/jammy 1.3-0ubuntu1 all
# swtpm-tools/jammy-updates 0.6.3-0ubuntu3.3 amd64
# swtpm/jammy-updates 0.6.3-0ubuntu3.3 amd64
# swupdate-doc/jammy 2021.11-1 all
# swupdate/jammy 2021.11-1 amd64
# sxhkd/jammy 0.6.2-1 amd64
# sxid/jammy 4.20130802-6 amd64
# sxiv/jammy 26-1 amd64
# sylfilter/jammy 0.8-7 amd64
# sylph-searcher/jammy 1.2.0-15 amd64
# sylpheed-doc/jammy 20140827-3 all
# sylpheed-i18n/jammy 3.7.0-8ubuntu3 all
# sylpheed-plugins/jammy 3.7.0-8ubuntu3 amd64
# sylpheed/jammy 3.7.0-8ubuntu3 amd64
# sylseg-sk/jammy 0.7.3-1 all
# symlinks/jammy 1.4-4 amd64
# symmetrica-doc/jammy 2.0+ds-6 all
# sympa/jammy 6.2.66~dfsg-2 amd64
# sympathy/jammy 1.2.1+woking+cvs+git20171124-1 amd64
# sympow-data/jammy 2.023.6-1 all
# sympow/jammy 2.023.6-1 amd64
# synapse/jammy 0.2.99.4-3build1 amd64
# synaptic/jammy 0.90.2build1 amd64
# sync-ui/jammy 2.0.0-3 amd64
# syncache/jammy 1.4-1.1 all
# syncevolution-common/jammy 2.0.0-3 all
# syncevolution-dbus/jammy 2.0.0-3 amd64
# syncevolution-http/jammy 2.0.0-3 all
# syncevolution-libs-gnome/jammy 2.0.0-3 amd64
# syncevolution-libs/jammy 2.0.0-3 amd64
# syncevolution/jammy 2.0.0-3 amd64
# syncmaildir-applet/jammy 1.3.0-1.1 amd64
# syncmaildir/jammy 1.3.0-1.1 amd64
# syncplay-common/jammy 1.6.9+repack1-4 all
# syncplay-server/jammy 1.6.9+repack1-4 all
# syncplay/jammy 1.6.9+repack1-4 all
# syncthing-discosrv/jammy-updates,jammy-security 1.18.0~ds1-3ubuntu0.3 amd64
# syncthing-gtk/jammy 0.9.4.4+ds+git20220108+9023143f8b93-1 all
# syncthing-relaysrv/jammy-updates,jammy-security 1.18.0~ds1-3ubuntu0.3 amd64
# syncthing/jammy-updates,jammy-security 1.18.0~ds1-3ubuntu0.3 amd64
# syndie/jammy 1.107b-5 all
# synfig-examples/jammy 1.4.0+dfsg-2.1ubuntu2 all
# synfig/jammy 1.4.0+dfsg-2.1ubuntu2 amd64
# synfigstudio/jammy 1.4.0+dfsg-1ubuntu2 amd64
# synthv1-common/jammy 0.9.24-1 all
# synthv1-lv2/jammy 0.9.24-1 amd64
# synthv1/jammy 0.9.24-1 amd64
# syrep/jammy 0.9-5 amd64
# syrthes-gui/jammy 4.3.5+20200129-dfsg1-1build1 all
# syrthes-tests/jammy 4.3.5+20200129-dfsg1-1build1 all
# syrthes-tools/jammy 4.3.5+20200129-dfsg1-1build1 amd64
# syrthes/jammy 4.3.5+20200129-dfsg1-1build1 amd64
# sysbench/jammy 1.0.20+ds-2 amd64
# sysconftool/jammy 0.17-1 amd64
# sysdig-dkms/jammy-updates 0.27.1-0.3ubuntu0.5 all
# sysdig/jammy-updates 0.27.1-0.3ubuntu0.5 amd64
# sysfsutils/jammy 2.1.1-1build1 amd64
# syslinux-common/jammy 3:6.04~git20190206.bf6db5b4+dfsg1-3ubuntu1 all
# syslinux-efi/jammy 3:6.04~git20190206.bf6db5b4+dfsg1-3ubuntu1 all
# syslinux-utils/jammy 3:6.04~git20190206.bf6db5b4+dfsg1-3ubuntu1 amd64
# syslinux/jammy 3:6.04~git20190206.bf6db5b4+dfsg1-3ubuntu1 amd64
# syslog-ng-core/jammy 3.35.1-1 amd64
# syslog-ng-dbg/jammy 3.35.1-1 amd64
# syslog-ng-dev/jammy 3.35.1-1 amd64
# syslog-ng-mod-add-contextual-data/jammy 3.35.1-1 amd64
# syslog-ng-mod-amqp/jammy 3.35.1-1 amd64
# syslog-ng-mod-examples/jammy 3.35.1-1 amd64
# syslog-ng-mod-extra/jammy 3.35.1-1 all
# syslog-ng-mod-geoip2/jammy 3.35.1-1 amd64
# syslog-ng-mod-getent/jammy 3.35.1-1 amd64
# syslog-ng-mod-graphite/jammy 3.35.1-1 amd64
# syslog-ng-mod-http/jammy 3.35.1-1 amd64
# syslog-ng-mod-map-value-pairs/jammy 3.35.1-1 amd64
# syslog-ng-mod-mongodb/jammy 3.35.1-1 amd64
# syslog-ng-mod-python/jammy 3.35.1-1 amd64
# syslog-ng-mod-rdkafka/jammy 3.35.1-1 amd64
# syslog-ng-mod-redis/jammy 3.35.1-1 amd64
# syslog-ng-mod-riemann/jammy 3.35.1-1 amd64
# syslog-ng-mod-slog/jammy 3.35.1-1 amd64
# syslog-ng-mod-smtp/jammy 3.35.1-1 amd64
# syslog-ng-mod-snmp/jammy 3.35.1-1 amd64
# syslog-ng-mod-sql/jammy 3.35.1-1 amd64
# syslog-ng-mod-stardate/jammy 3.35.1-1 amd64
# syslog-ng-mod-stomp/jammy 3.35.1-1 amd64
# syslog-ng-mod-xml-parser/jammy 3.35.1-1 amd64
# syslog-ng/jammy 3.35.1-1 all
# syslogout/jammy 0.3.10 all
# sysnews/jammy 0.9+ds.1-1 amd64
# sysprof/jammy 3.44.0-1 amd64
# sysprofile/jammy 0.3.10 all
# sysrepo-doc/jammy 2.0.53-6build1 all
# sysrepo-plugind/jammy 2.0.53-6build1 amd64
# sysrepo/jammy 2.0.53-6build1 amd64
# sysrqd/jammy 14-1build1 amd64
# sysstat/jammy-updates,jammy-security 12.5.2-2ubuntu0.2 amd64
# system-config-printer-common/jammy 1.5.16-0ubuntu3 all
# system-config-printer-udev/jammy 1.5.16-0ubuntu3 amd64
# system-config-printer/jammy 1.5.16-0ubuntu3 all
# system-tools-backends-dev/jammy 2.10.2-3.1 all
# system-tools-backends/jammy 2.10.2-3.1 amd64
# systemctl/jammy 1.4.4181-1.1 all
# systemd-bootchart/jammy 234-1ubuntu1 amd64
# systemd-container/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-coredump/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-cron/jammy 1.15.18-1 amd64
# systemd-hwe-hwdb/jammy-updates 249.11.6 all
# systemd-journal-remote/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-oomd/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-repart/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-standalone-sysusers/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-standalone-tmpfiles/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-sysv/jammy-updates,now 249.11-0ubuntu3.20 amd64 [installed,automatic]
# systemd-tests/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-timesyncd/jammy-updates 249.11-0ubuntu3.20 amd64
# systemd-zram-generator/jammy 0.3.2-1 amd64
# systemd/jammy-updates,now 249.11-0ubuntu3.20 amd64 [installed,automatic]
# systempreferences.app-dbg/jammy 1.2.0-2build7 amd64
# systempreferences.app/jammy 1.2.0-2build7 amd64
# systemsettings/jammy-updates 4:5.24.6-0ubuntu0.1 amd64
# systemtap-client/jammy 4.6-2 amd64
# systemtap-common/jammy 4.6-2 amd64
# systemtap-doc/jammy 4.6-2 amd64
# systemtap-runtime/jammy 4.6-2 amd64
# systemtap-sdt-dev/jammy 4.6-2 amd64
# systemtap-server/jammy 4.6-2 amd64
# systemtap/jammy 4.6-2 amd64
# systraq/jammy 20201231-1 all
# systray-mdstat/jammy 1.2.0-2 all
# systune/jammy 0.5.13 all
# sysuser-helper/jammy 1.3.7+really1.4.1 all
# sysvbanner/jammy 1:1.0-17fakesync1 amd64
# sysvinit-utils/jammy,now 3.01-1ubuntu1 amd64 [installed]
# t-code-common/jammy 2:2.3.1-9 all
# t-code/jammy 2:2.3.1-9 all
# t-coffee-examples/jammy 13.41.0.28bdc39+dfsg-4 all
# t-coffee/jammy 13.41.0.28bdc39+dfsg-4 amd64
# t-prot/jammy 3.4-4.1 all
# t1-cyrillic/jammy 4.18 all
# t1-oldslavic/jammy 4.18 all
# t1-teams/jammy 4.18 all
# t1-xfree86-nonfree/jammy 4.2.1-8 all
# t1utils/jammy 1.41-4build2 amd64
# t2html/jammy 2020.08.19+git2d9159d-1 all
# t2n/jammy 0.6-9 amd64
# t3highlight/jammy 0.5.0-1 amd64
# t50/jammy 5.8.7b-1 amd64
# tabble/jammy 0.45-2 amd64
# tabix/jammy 1.13+ds-2build1 amd64
# tableau-parm/jammy-updates 0.2.0-6build0.1 amd64
# tablet-encode/jammy 2.30-0.1ubuntu1 all
# tablix2/jammy 0.3.5-3.1 amd64
# tachyon-bin-nox/jammy 0.99~b6+dsx-10 amd64
# tachyon-bin-ogl/jammy 0.99~b6+dsx-10 amd64
# tachyon-doc/jammy 0.99~b6+dsx-10 all
# tachyon/jammy 0.99~b6+dsx-10 all
# tack/jammy 1.08-1build1 amd64
# taffybar/jammy 3.2.2-2build1.1 amd64
# tagcloud/jammy 1.4-1.2 all
# tagcoll/jammy 2.0.14-2build1 amd64
# taggrepper/jammy 0.05-5 amd64
# taglog/jammy 0.2.6-1 all
# tagua-data/jammy 1.0~alpha2-16-g618c6a0-3build1 all
# tagua/jammy 1.0~alpha2-16-g618c6a0-3build1 amd64
# taktuk/jammy 3.7.7-2 all
# tali/jammy 1:40.6-1 amd64
# talk/jammy 0.17-17 amd64
# talkd/jammy 0.17-17 amd64
# talksoup.app/jammy 1.0alpha-32-g55b4d4e-2build7 amd64
# tamil-gtk2im/jammy 2.2-6 amd64
# tandem-mass/jammy 1:201702011-1build1 amd64
# tang-common/jammy-updates,jammy-security 11-1ubuntu0.1 amd64
# tang-nagios/jammy 7-2 amd64
# tang-xinetd/jammy-updates,jammy-security 11-1ubuntu0.1 all
# tang/jammy-updates,jammy-security 11-1ubuntu0.1 all
# tangerine-dbg/jammy 0.3.4-6.1 amd64
# tangerine-icon-theme/jammy 0.27ubuntu1 all
# tangerine/jammy 0.3.4-6.1 amd64
# tanglet-data/jammy 1.6.1.1-1 all
# tanglet/jammy 1.6.1.1-1 amd64
# tango-accesscontrol/jammy 9.2.5a+dfsg1-2ubuntu1 amd64
# tango-common/jammy 9.2.5a+dfsg1-2ubuntu1 all
# tango-db/jammy 9.2.5a+dfsg1-2ubuntu1 amd64
# tango-icon-theme-common/jammy 0.7-0ubuntu3 all
# tango-icon-theme-extras/jammy 0.1.0-0ubuntu6 all
# tango-icon-theme/jammy 0.8.90-8 all
# tango-starter/jammy 9.2.5a+dfsg1-2ubuntu1 amd64
# tango-test/jammy 9.2.5a+dfsg1-2ubuntu1 amd64
# tantan/jammy 26-1 amd64
# tao-config-dev/jammy 0.0+git20200604.84a7383-2 all
# tao-config-examples/jammy 0.0+git20200604.84a7383-2 all
# tao-json-dev/jammy 0.0+git20200604.f357d72-2 all
# tao-json-examples/jammy 0.0+git20200604.f357d72-2 all
# tao-pegtl-dev/jammy 2.8.3-3 all
# taopm/jammy 1.0-7 amd64
# tap-plugins-doc/jammy 20140526-3.1 all
# tap-plugins/jammy 1.0.0-1 amd64
# tapecalc/jammy 20220117-1 amd64
# tappy/jammy 3.1-1 all
# taptempo/jammy 1.4.5-1 amd64
# tar-doc/jammy 1.34-1 all
# tar-scripts/jammy-updates,jammy-security 1.34+dfsg-1ubuntu0.1.22.04.2 amd64
# tar-split/jammy 0.11.1-2 amd64
# tar/jammy-updates,jammy-security,now 1.34+dfsg-1ubuntu0.1.22.04.2 amd64 [installed]
# tarantool-common/jammy 2.6.0-1ubuntu3 all
# tarantool-dev/jammy 2.6.0-1ubuntu3 amd64
# tarantool/jammy 2.6.0-1ubuntu3 amd64
# tardiff/jammy 0.1-6 all
# tardy/jammy 1.25-1build2 amd64
# targetcli-fb/jammy 1:2.1.53-1ubuntu3 all
# tarlz/jammy 0.22-1 amd64
# tart/jammy 3.10-1build1 amd64
# task-albanian-desktop/jammy 3.68ubuntu2 all
# task-amharic-desktop/jammy 3.68ubuntu2 all
# task-amharic-gnome-desktop/jammy 3.68ubuntu2 all
# task-amharic-kde-desktop/jammy 3.68ubuntu2 all
# task-amharic/jammy 3.68ubuntu2 all
# task-arabic-desktop/jammy 3.68ubuntu2 all
# task-arabic-kde-desktop/jammy 3.68ubuntu2 all
# task-arabic/jammy 3.68ubuntu2 all
# task-asturian-desktop/jammy 3.68ubuntu2 all
# task-asturian/jammy 3.68ubuntu2 all
# task-basque-desktop/jammy 3.68ubuntu2 all
# task-basque-kde-desktop/jammy 3.68ubuntu2 all
# task-basque/jammy 3.68ubuntu2 all
# task-belarusian-desktop/jammy 3.68ubuntu2 all
# task-belarusian-kde-desktop/jammy 3.68ubuntu2 all
# task-belarusian/jammy 3.68ubuntu2 all
# task-bengali-desktop/jammy 3.68ubuntu2 all
# task-bengali-kde-desktop/jammy 3.68ubuntu2 all
# task-bengali/jammy 3.68ubuntu2 all
# task-bosnian-desktop/jammy 3.68ubuntu2 all
# task-bosnian-kde-desktop/jammy 3.68ubuntu2 all
# task-bosnian/jammy 3.68ubuntu2 all
# task-brazilian-portuguese-desktop/jammy 3.68ubuntu2 all
# task-brazilian-portuguese-kde-desktop/jammy 3.68ubuntu2 all
# task-brazilian-portuguese/jammy 3.68ubuntu2 all
# task-british-desktop/jammy 3.68ubuntu2 all
# task-british-kde-desktop/jammy 3.68ubuntu2 all
# task-bulgarian-desktop/jammy 3.68ubuntu2 all
# task-bulgarian-kde-desktop/jammy 3.68ubuntu2 all
# task-bulgarian/jammy 3.68ubuntu2 all
# task-catalan-desktop/jammy 3.68ubuntu2 all
# task-catalan-kde-desktop/jammy 3.68ubuntu2 all
# task-catalan/jammy 3.68ubuntu2 all
# task-chinese-s-desktop/jammy 3.68ubuntu2 all
# task-chinese-s-gnome-desktop/jammy 3.68ubuntu2 all
# task-chinese-s-kde-desktop/jammy 3.68ubuntu2 all
# task-chinese-s/jammy 3.68ubuntu2 all
# task-chinese-t-desktop/jammy 3.68ubuntu2 all
# task-chinese-t-gnome-desktop/jammy 3.68ubuntu2 all
# task-chinese-t-kde-desktop/jammy 3.68ubuntu2 all
# task-chinese-t/jammy 3.68ubuntu2 all
# task-cinnamon-desktop/jammy 3.68ubuntu2 all
# task-croatian-desktop/jammy 3.68ubuntu2 all
# task-croatian-kde-desktop/jammy 3.68ubuntu2 all
# task-croatian/jammy 3.68ubuntu2 all
# task-cyrillic-desktop/jammy 3.68ubuntu2 all
# task-cyrillic-kde-desktop/jammy 3.68ubuntu2 all
# task-cyrillic/jammy 3.68ubuntu2 all
# task-czech-desktop/jammy 3.68ubuntu2 all
# task-czech-kde-desktop/jammy 3.68ubuntu2 all
# task-czech/jammy 3.68ubuntu2 all
# task-danish-desktop/jammy 3.68ubuntu2 all
# task-danish-kde-desktop/jammy 3.68ubuntu2 all
# task-danish/jammy 3.68ubuntu2 all
# task-desktop/jammy 3.68ubuntu2 all
# task-dutch-desktop/jammy 3.68ubuntu2 all
# task-dutch-kde-desktop/jammy 3.68ubuntu2 all
# task-dutch/jammy 3.68ubuntu2 all
# task-dzongkha-desktop/jammy 3.68ubuntu2 all
# task-dzongkha-kde-desktop/jammy 3.68ubuntu2 all
# task-english/jammy 3.68ubuntu2 all
# task-esperanto-desktop/jammy 3.68ubuntu2 all
# task-esperanto-kde-desktop/jammy 3.68ubuntu2 all
# task-esperanto/jammy 3.68ubuntu2 all
# task-estonian-desktop/jammy 3.68ubuntu2 all
# task-estonian-kde-desktop/jammy 3.68ubuntu2 all
# task-estonian/jammy 3.68ubuntu2 all
# task-finnish-desktop/jammy 3.68ubuntu2 all
# task-finnish-kde-desktop/jammy 3.68ubuntu2 all
# task-finnish/jammy 3.68ubuntu2 all
# task-french-desktop/jammy 3.68ubuntu2 all
# task-french-kde-desktop/jammy 3.68ubuntu2 all
# task-french/jammy 3.68ubuntu2 all
# task-galician-desktop/jammy 3.68ubuntu2 all
# task-galician-kde-desktop/jammy 3.68ubuntu2 all
# task-galician/jammy 3.68ubuntu2 all
# task-georgian-desktop/jammy 3.68ubuntu2 all
# task-german-desktop/jammy 3.68ubuntu2 all
# task-german-kde-desktop/jammy 3.68ubuntu2 all
# task-german/jammy 3.68ubuntu2 all
# task-gnome-desktop/jammy 3.68ubuntu2 all
# task-gnome-flashback-desktop/jammy 3.68ubuntu2 all
# task-greek-desktop/jammy 3.68ubuntu2 all
# task-greek-kde-desktop/jammy 3.68ubuntu2 all
# task-greek/jammy 3.68ubuntu2 all
# task-gujarati-desktop/jammy 3.68ubuntu2 all
# task-gujarati-kde-desktop/jammy 3.68ubuntu2 all
# task-gujarati/jammy 3.68ubuntu2 all
# task-hebrew-desktop/jammy 3.68ubuntu2 all
# task-hebrew-gnome-desktop/jammy 3.68ubuntu2 all
# task-hebrew-kde-desktop/jammy 3.68ubuntu2 all
# task-hebrew/jammy 3.68ubuntu2 all
# task-hindi-desktop/jammy 3.68ubuntu2 all
# task-hindi-kde-desktop/jammy 3.68ubuntu2 all
# task-hindi/jammy 3.68ubuntu2 all
# task-hungarian-desktop/jammy 3.68ubuntu2 all
# task-hungarian-kde-desktop/jammy 3.68ubuntu2 all
# task-hungarian/jammy 3.68ubuntu2 all
# task-icelandic-desktop/jammy 3.68ubuntu2 all
# task-icelandic-kde-desktop/jammy 3.68ubuntu2 all
# task-icelandic/jammy 3.68ubuntu2 all
# task-indonesian-desktop/jammy 3.68ubuntu2 all
# task-indonesian-kde-desktop/jammy 3.68ubuntu2 all
# task-irish-desktop/jammy 3.68ubuntu2 all
# task-irish-kde-desktop/jammy 3.68ubuntu2 all
# task-irish/jammy 3.68ubuntu2 all
# task-italian-desktop/jammy 3.68ubuntu2 all
# task-italian-kde-desktop/jammy 3.68ubuntu2 all
# task-italian/jammy 3.68ubuntu2 all
# task-japanese-desktop/jammy 3.68ubuntu2 all
# task-japanese-gnome-desktop/jammy 3.68ubuntu2 all
# task-japanese-kde-desktop/jammy 3.68ubuntu2 all
# task-japanese/jammy 3.68ubuntu2 all
# task-kannada-desktop/jammy 3.68ubuntu2 all
# task-kannada-gnome-desktop/jammy 3.68ubuntu2 all
# task-kannada-kde-desktop/jammy 3.68ubuntu2 all
# task-kazakh-desktop/jammy 3.68ubuntu2 all
# task-kazakh-kde-desktop/jammy 3.68ubuntu2 all
# task-kazakh/jammy 3.68ubuntu2 all
# task-kde-desktop/jammy 3.68ubuntu2 all
# task-khmer-desktop/jammy 3.68ubuntu2 all
# task-khmer-kde-desktop/jammy 3.68ubuntu2 all
# task-khmer/jammy 3.68ubuntu2 all
# task-korean-desktop/jammy 3.68ubuntu2 all
# task-korean-gnome-desktop/jammy 3.68ubuntu2 all
# task-korean-kde-desktop/jammy 3.68ubuntu2 all
# task-korean/jammy 3.68ubuntu2 all
# task-kurdish-desktop/jammy 3.68ubuntu2 all
# task-kurdish-kde-desktop/jammy 3.68ubuntu2 all
# task-kurdish/jammy 3.68ubuntu2 all
# task-laptop/jammy 3.68ubuntu2 all
# task-latvian-desktop/jammy 3.68ubuntu2 all
# task-latvian-kde-desktop/jammy 3.68ubuntu2 all
# task-latvian/jammy 3.68ubuntu2 all
# task-lithuanian-desktop/jammy 3.68ubuntu2 all
# task-lithuanian-kde-desktop/jammy 3.68ubuntu2 all
# task-lithuanian/jammy 3.68ubuntu2 all
# task-lxde-desktop/jammy 3.68ubuntu2 all
# task-lxqt-desktop/jammy 3.68ubuntu2 all
# task-macedonian-desktop/jammy 3.68ubuntu2 all
# task-macedonian-kde-desktop/jammy 3.68ubuntu2 all
# task-macedonian/jammy 3.68ubuntu2 all
# task-malayalam-desktop/jammy 3.68ubuntu2 all
# task-malayalam-gnome-desktop/jammy 3.68ubuntu2 all
# task-malayalam-kde-desktop/jammy 3.68ubuntu2 all
# task-malayalam/jammy 3.68ubuntu2 all
# task-marathi-desktop/jammy 3.68ubuntu2 all
# task-marathi/jammy 3.68ubuntu2 all
# task-mate-desktop/jammy 3.68ubuntu2 all
# task-nepali-desktop/jammy 3.68ubuntu2 all
# task-nepali-kde-desktop/jammy 3.68ubuntu2 all
# task-northern-sami-desktop/jammy 3.68ubuntu2 all
# task-northern-sami/jammy 3.68ubuntu2 all
# task-norwegian-desktop/jammy 3.68ubuntu2 all
# task-norwegian-kde-desktop/jammy 3.68ubuntu2 all
# task-norwegian/jammy 3.68ubuntu2 all
# task-persian-desktop/jammy 3.68ubuntu2 all
# task-persian-kde-desktop/jammy 3.68ubuntu2 all
# task-persian/jammy 3.68ubuntu2 all
# task-polish-desktop/jammy 3.68ubuntu2 all
# task-polish-kde-desktop/jammy 3.68ubuntu2 all
# task-polish/jammy 3.68ubuntu2 all
# task-portuguese-desktop/jammy 3.68ubuntu2 all
# task-portuguese-kde-desktop/jammy 3.68ubuntu2 all
# task-portuguese/jammy 3.68ubuntu2 all
# task-punjabi-desktop/jammy 3.68ubuntu2 all
# task-punjabi-kde-desktop/jammy 3.68ubuntu2 all
# task-punjabi/jammy 3.68ubuntu2 all
# task-romanian-desktop/jammy 3.68ubuntu2 all
# task-romanian-kde-desktop/jammy 3.68ubuntu2 all
# task-romanian/jammy 3.68ubuntu2 all
# task-russian-desktop/jammy 3.68ubuntu2 all
# task-russian-kde-desktop/jammy 3.68ubuntu2 all
# task-russian/jammy 3.68ubuntu2 all
# task-serbian-desktop/jammy 3.68ubuntu2 all
# task-serbian-kde-desktop/jammy 3.68ubuntu2 all
# task-serbian/jammy 3.68ubuntu2 all
# task-sinhala-desktop/jammy 3.68ubuntu2 all
# task-sinhala-kde-desktop/jammy 3.68ubuntu2 all
# task-slovak-desktop/jammy 3.68ubuntu2 all
# task-slovak-kde-desktop/jammy 3.68ubuntu2 all
# task-slovak/jammy 3.68ubuntu2 all
# task-slovenian-desktop/jammy 3.68ubuntu2 all
# task-slovenian-kde-desktop/jammy 3.68ubuntu2 all
# task-slovenian/jammy 3.68ubuntu2 all
# task-south-african-english-desktop/jammy 3.68ubuntu2 all
# task-spanish-desktop/jammy 3.68ubuntu2 all
# task-spanish-kde-desktop/jammy 3.68ubuntu2 all
# task-spanish/jammy 3.68ubuntu2 all
# task-spooler/jammy 1.0.1+dfsg1-1 amd64
# task-ssh-server/jammy 3.68ubuntu2 all
# task-swedish-desktop/jammy 3.68ubuntu2 all
# task-swedish-kde-desktop/jammy 3.68ubuntu2 all
# task-swedish/jammy 3.68ubuntu2 all
# task-tagalog/jammy 3.68ubuntu2 all
# task-tamil-desktop/jammy 3.68ubuntu2 all
# task-tamil-gnome-desktop/jammy 3.68ubuntu2 all
# task-tamil/jammy 3.68ubuntu2 all
# task-telugu-desktop/jammy 3.68ubuntu2 all
# task-telugu-gnome-desktop/jammy 3.68ubuntu2 all
# task-telugu-kde-desktop/jammy 3.68ubuntu2 all
# task-telugu/jammy 3.68ubuntu2 all
# task-thai-desktop/jammy 3.68ubuntu2 all
# task-thai-gnome-desktop/jammy 3.68ubuntu2 all
# task-thai-kde-desktop/jammy 3.68ubuntu2 all
# task-thai/jammy 3.68ubuntu2 all
# task-turkish-desktop/jammy 3.68ubuntu2 all
# task-turkish-kde-desktop/jammy 3.68ubuntu2 all
# task-turkish/jammy 3.68ubuntu2 all
# task-ukrainian-desktop/jammy 3.68ubuntu2 all
# task-ukrainian-kde-desktop/jammy 3.68ubuntu2 all
# task-ukrainian/jammy 3.68ubuntu2 all
# task-uyghur-desktop/jammy 3.68ubuntu2 all
# task-uyghur-kde-desktop/jammy 3.68ubuntu2 all
# task-vietnamese-desktop/jammy 3.68ubuntu2 all
# task-vietnamese-kde-desktop/jammy 3.68ubuntu2 all
# task-web-server/jammy 3.68ubuntu2 all
# task-welsh-desktop/jammy 3.68ubuntu2 all
# task-welsh/jammy 3.68ubuntu2 all
# task-xfce-desktop/jammy 3.68ubuntu2 all
# task-xhosa-desktop/jammy 3.68ubuntu2 all
# task-xhosa-kde-desktop/jammy 3.68ubuntu2 all
# taskd/jammy 1.1.0+dfsg-4 amd64
# tasksel-data/jammy 3.68ubuntu2 all
# tasksel/jammy 3.68ubuntu2 all
# tasksh/jammy 1.2.0-1build2 amd64
# taskwarrior/jammy 2.6.1+dfsg-1 amd64
# tasque/jammy 0.1.12-4.1ubuntu1 all
# tasty-discover/jammy 4.2.1-2build4.1 amd64
# tatan/jammy 1.0.dfsg2-0.1build2 amd64
# tayga/jammy 0.9.2-8 amd64
# tboot/jammy 1.10.2+dfsg.0-1ubuntu1 amd64
# tcc/jammy 0.9.27+git20200814.62c30a4a-1 amd64
# tcd-utils/jammy 20061127-2build1 amd64
# tcl-awthemes/jammy 10.4.0-1 all
# tcl-combat/jammy 0.8.1-1 all
# tcl-dev/jammy,now 8.6.11+1build2 amd64 [installed]
# tcl-doc/jammy 8.6.11+1build2 all
# tcl-expect-dev/jammy 5.45.4-2build1 amd64
# tcl-expect/jammy 5.45.4-2build1 amd64
# tcl-fitstcl/jammy 2.4-4build2 amd64
# tcl-funtools/jammy 1.4.8-1 amd64
# tcl-hamlib/jammy 4.3.1-1build2 amd64
# tcl-itcl4-dev/jammy 4.2.2-1 amd64
# tcl-itcl4-doc/jammy 4.2.2-1 all
# tcl-itcl4/jammy 4.2.2-1 amd64
# tcl-memchan-dev/jammy 2.3+dfsg-1 amd64
# tcl-memchan/jammy 2.3+dfsg-1 amd64
# tcl-signal/jammy 1.4.4.1-2 amd64
# tcl-snack-dev/jammy 2.2.10.20090623-dfsg-10 amd64
# tcl-snack-doc/jammy 2.2.10.20090623-dfsg-10 all
# tcl-snack/jammy 2.2.10.20090623-dfsg-10 amd64
# tcl-sugar/jammy 0.1-1.1 all
# tcl-tclex/jammy 1.2a1-17 amd64
# tcl-tclreadline/jammy 2.3.8-1 amd64
# tcl-thread/jammy 1:2.8.7-1 amd64
# tcl-tls/jammy 1.7.22-2ubuntu1 amd64
# tcl-trf-dev/jammy 2.1.4-dfsg3-2.1build1 amd64
# tcl-trf-doc/jammy 2.1.4-dfsg3-2.1build1 all
# tcl-trf/jammy 2.1.4-dfsg3-2.1build1 amd64
# tcl-ttkthemes/jammy 3.2.2+git20220101+07e6509cc6bf-1 all
# tcl-udp/jammy 1.0.11-2 amd64
# tcl-vfs/jammy 1.4.2~20121213-2 amd64
# tcl-vtk7/jammy 7.1.1+dfsg2-10.1build2+jammy0 amd64
# tcl-xmlrpc/jammy 0.3-3 all
# tcl-xpa/jammy 2.1.20-1 amd64
# tcl-yajltcl/jammy 1.7.0-4 amd64
# tcl3270/jammy 4.1ga10-1.1 amd64
# tcl8.6-dev/jammy,now 8.6.12+dfsg-1build1 amd64 [installed,automatic]
# tcl8.6-doc/jammy 8.6.12+dfsg-1build1 all
# tcl8.6-tdbc-mysql/jammy 1.1.3-2ubuntu1 amd64
# tcl8.6-tdbc-odbc/jammy 1.1.3-2 amd64
# tcl8.6-tdbc-postgres/jammy 1.1.3-2 amd64
# tcl8.6-tdbc-sqlite3/jammy 1.1.3-2 all
# tcl8.6-tdbc/jammy 1.1.3-2 amd64
# tcl8.6/jammy,now 8.6.12+dfsg-1build1 amd64 [installed,automatic]
# tcl/jammy,now 8.6.11+1build2 amd64 [installed,automatic]
# tclcl-dbg/jammy 1.20-9.1 amd64
# tclcl-dev/jammy 1.20-9.1 all
# tclcl/jammy 1.20-9.1 amd64
# tclcurl/jammy 7.22.0+hg20160822-3 amd64
# tclfitsy/jammy 8.3+repack-1 amd64
# tclgeoip/jammy 0.2-1.1 amd64
# tcliis/jammy 8.3+repack-1 amd64
# tcllib-critcl/jammy 1.20+dfsg-1 amd64
# tcllib/jammy,now 1.20+dfsg-1 all [installed]
# tclodbc/jammy 2.5.1-2build1 amd64
# tclsoldout/jammy 0.1.1-2 amd64
# tclspice/jammy-updates 36+ds-1ubuntu0.1 amd64
# tclws/jammy 3.4.0-2 all
# tclx8.4-dev/jammy 8.4.1-4 amd64
# tclx8.4-doc/jammy 8.4.1-4 all
# tclx8.4/jammy 8.4.1-4 amd64
# tclxapian/jammy 1.4.18-2build3 amd64
# tclxml-dev/jammy 1:3.2.7-5 amd64
# tclxml/jammy 1:3.2.7-5 amd64
# tcm-doc/jammy 2.20+TSQD-7 all
# tcm/jammy 2.20+TSQD-7 amd64
# tcmu-runner/jammy 1.5.4-2 amd64
# tcode/jammy 0.1.20080918-4 all
# tcpd/jammy 7.6.q-31build2 amd64
# tcpdump/jammy-updates 4.99.1-3ubuntu0.2 amd64
# tcpflow-nox/jammy 1.6.1-2build1 amd64
# tcpflow/jammy 1.6.1-2build1 amd64
# tcpick/jammy 0.2.1-10 amd64
# tcplay/jammy 1.1-6 amd64
# tcpreen/jammy 1.4.4-2ubuntu3 amd64
# tcpreplay/jammy 4.3.4-1 amd64
# tcpslice/jammy 1.3-2 amd64
# tcpspy/jammy 1.7d-15 amd64
# tcpstat/jammy 1.5-8build1 amd64
# tcptrace/jammy 6.6.7-6 amd64
# tcptraceroute/jammy 1.5beta7+debian-4.1 amd64
# tcptrack/jammy 1.4.3-1 amd64
# tcputils/jammy 0.6.2-10build1 amd64
# tcpxtract/jammy 1.0.1-16 amd64
# tcs/jammy 1-11.1 amd64
# tcsh/jammy 6.21.00-1.1 amd64
# tcvt/jammy 0.1.20171010-5 all
# td2planet/jammy 0.3.0-4 all
# tdb-tools/jammy 1.4.5-2build1 amd64
# tdc/jammy 1.9-3 amd64
# tdfsb/jammy 0.0.10-3 amd64
# tdiary-contrib/jammy 5.2.0-2 all
# tdiary-core/jammy 5.2.0-2 all
# tdiary-mode/jammy 5.2.0-2 all
# tdiary-style-gfm/jammy 1.2.0-1 all
# tdiary-style-rd/jammy 0.0.3-4 all
# tdiary-theme/jammy 5.2.0-2 all
# tdiary/jammy 5.2.0-2 all
# tdom-dev/jammy 0.9.2-1 amd64
# tdom/jammy 0.9.2-1 amd64
# tdsodbc/jammy 1.3.6-1 amd64
# te923con/jammy 0.6.1-6 amd64
# tea-data/jammy 50.0.4-1 all
# tea/jammy 50.0.4-1 amd64
# teckit/jammy 2.5.11+ds1-1 amd64
# tecnoballz-data/jammy 0.93.1-10 all
# tecnoballz/jammy 0.93.1-10 amd64
# teem-apps/jammy 1.12.0~20160122-4 amd64
# teensy-loader-cli/jammy 2.2-1 amd64
# teeworlds-data/jammy 0.7.5-1 all
# teeworlds-server/jammy 0.7.5-1 amd64
# teeworlds/jammy 0.7.5-1 amd64
# teg/jammy 0.12.0-2 amd64
# tegaki-zinnia-japanese/jammy 0.3-2 all
# tegaki-zinnia-simplified-chinese/jammy 0.3-2 all
# tegaki-zinnia-traditional-chinese/jammy 0.3-0ubuntu1 all
# tegrarcm/jammy 1.8-2 amd64
# telegnome/jammy 0.3.6-1 amd64
# telegraf/jammy 1.21.4+ds1-0ubuntu2 amd64
# telegram-cli/jammy 1.3.1+git20160323.6547c0b21-3 amd64
# telegram-desktop/jammy 3.6.1+ds-2build1 amd64
# telegram-purple/jammy 1.4.3-3ubuntu3 amd64
# telemetry-tempest-plugin/jammy 1.5.0-2 all
# telepathy-accounts-signon/jammy 2.1-1 amd64
# telepathy-gabble-tests/jammy 0.18.4-4 amd64
# telepathy-gabble/jammy 0.18.4-4 amd64
# telepathy-haze/jammy 0.8.0-3 amd64
# telepathy-idle/jammy 0.2.2-1 amd64
# telepathy-indicator/jammy 0.3.1+14.10.20140908-0ubuntu3 amd64
# telepathy-logger/jammy 0.8.2-4 amd64
# telepathy-mission-control-5/jammy 1:5.16.5-2ubuntu1 amd64
# telepathy-rakia/jammy 0.8.0-4 amd64
# telepathy-ring/jammy 2.3.24-2 amd64
# telepathy-salut/jammy 0.8.1-7 amd64
# telepathy-specification/jammy 0.27.4-1 all
# tellico-data/jammy 3.4.4-1 all
# tellico-doc/jammy 3.4.4-1 all
# tellico-scripts/jammy 3.4.4-1 all
# tellico/jammy 3.4.4-1 amd64
# telnet-ssl/jammy 0.17.41+0.2-3.3build2 amd64
# telnet/jammy 0.17-44build1 amd64
# telnetd-ssl/jammy 0.17.41+0.2-3.3build2 amd64
# telnetd/jammy 0.17-44build1 amd64
# tempest-for-eliza/jammy 1.0.5-2.1build1 amd64
# tempest/jammy 1:29.0.0-3 all
# tenace/jammy 0.17-1 amd64
# tenmado/jammy 0.10-4 amd64
# tennix/jammy 1.1-3.2build2 amd64
# tenshi/jammy 0.13-7 all
# tensorrt-dev/unknown 11.0.0.114-1+cuda13.2 amd64
# tensorrt-libs/unknown 11.0.0.114-1+cuda13.2 amd64
# tensorrt/unknown 11.0.0.114-1+cuda13.2 amd64
# tercpp/jammy 0.6.2+svn46-1.1build2 amd64
# termdebug/jammy 2.2+dfsg-1build4 amd64
# terminal.app/jammy 0.9.9-3build2 amd64
# terminator/jammy 2.1.1-1 all
# terminatorx/jammy 4.1.0-1 amd64
# termineter/jammy 1.0.4-2 all
# terminews/jammy-updates,jammy-security 1.2.2-1ubuntu0.22.04.3 amd64
# terminfo/jammy 0.0~git20210125.ca9a967-1 amd64
# terminology-data/jammy 1.12.1-1 all
# terminology/jammy 1.12.1-1 amd64
# terminus/jammy 1.14.1-1 amd64
# termit/jammy 3.1-1 amd64
# termonad/jammy 4.0.0.1-2 amd64
# termrec/jammy 0.19-1 amd64
# termshark/jammy-updates,jammy-security 2.2.0-2ubuntu0.22.04.3 amd64
# termtosvg/jammy 1.1.0+dfsg-3 all
# termtris/jammy 1.3-1ubuntu1 amd64
# terraintool/jammy 1.16-3 all
# teseq/jammy 1.1.1-1 amd64
# tesseract-ocr-afr/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-all/jammy 4.1.1-2.1build1 all
# tesseract-ocr-amh/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-ara/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-asm/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-aze-cyrl/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-aze/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-bel/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-ben/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-bod/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-bos/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-bre/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-bul/jammy 1:4.00~git30-7274cfa-1.1 all
# tesseract-ocr-cat/jammy 1:4.00~git30-7274cfa-1.1 all
# ...
# xubuntu-community-wallpapers-focal/jammy 22.04.0 all
# xubuntu-community-wallpapers-jammy/jammy 22.04.0 all
# xubuntu-community-wallpapers-trusty/jammy 22.04.0 all
# xubuntu-community-wallpapers-xenial/jammy 22.04.0 all
# xubuntu-community-wallpapers/jammy 22.04.0 all
# xubuntu-core/jammy 2.241 amd64
# xubuntu-default-settings/jammy 22.04.0 all
# xubuntu-desktop/jammy 2.241 amd64
# xubuntu-docs/jammy 22.04 all
# xubuntu-icon-theme/jammy 22.04.1 all
# xubuntu-live-settings/jammy 22.04.0 all
# xubuntu-restricted-addons/jammy 26 all
# xubuntu-wallpapers/jammy 22.04.1 all
# xul-ext-calendar-timezones/jammy-updates,jammy-security 1:140.7.1+build1-0ubuntu0.22.04.1 amd64
# xul-ext-exteditor/jammy 2.0.4-1 all
# xul-ext-gdata-provider/jammy-updates,jammy-security 1:140.7.1+build1-0ubuntu0.22.04.1 amd64
# xul-ext-lightning/jammy-updates,jammy-security 1:140.7.1+build1-0ubuntu0.22.04.1 amd64
# xul-ext-ubufox/jammy 3.4-0ubuntu1.17.10.1 all
# xutils-dev/jammy 1:7.7+6ubuntu1 amd64
# xutils/jammy 1:7.7+23ubuntu2 all
# xva-img/jammy 1.4.2-1build1 amd64
# xvattr/jammy 1.3-0.6ubuntu2 amd64
# xvfb/jammy-updates,jammy-security,now 2:21.1.4-2ubuntu1.7~22.04.16 amd64 [installed]
# xvid4conf/jammy 1.12-dmo2ubuntu2 amd64
# xvidenc/jammy 8.4.3~dfsg-0ubuntu1 all
# xvier/jammy 1.0-7.6 amd64
# xvile/jammy 9.8v-1build1 amd64
# xvkbd/jammy 4.1-1 amd64
# xwallpaper/jammy 0.7.3-1 amd64
# xwatch/jammy 2.11-16 amd64
# xwax/jammy 1.8-1 amd64
# xwayland-hwe-18.04/jammy 3:14.6 amd64
# xwayland/jammy-updates,jammy-security 2:22.1.1-1ubuntu0.20 amd64
# xwelltris/jammy 1.0.1-18 amd64
# xwiimote/jammy 2-4 amd64
# xwit/jammy 3.4-16 amd64
# xwpe/jammy 1.5.30a-3 amd64
# xwrited/jammy 3-1 amd64
# xwrits/jammy 2.21-6.1build1 amd64
# xxd/jammy-updates,jammy-security,now 2:8.2.3995-1ubuntu2.30 amd64 [installed,automatic]
# xxdiff-scripts/jammy-updates 1:5.0~b1+git20211103+dfsg-1ubuntu0.1 all
# xxdiff/jammy-updates 1:5.0~b1+git20211103+dfsg-1ubuntu0.1 amd64
# xxhash/jammy 0.8.1-1 amd64
# xxkb/jammy 1.11.1-1 amd64
# xye-data/jammy 0.12.2+dfsg-11 all
# xye/jammy 0.12.2+dfsg-11 amd64
# xygrib-maps/jammy 1.2.6.1-3~jammy0 all
# xygrib/jammy 1.2.6.1-3~jammy0 amd64
# xymon-client/jammy-updates 4.3.30-1ubuntu0.1 amd64
# xymon/jammy-updates 4.3.30-1ubuntu0.1 amd64
# xymonq/jammy 0.8-1 all
# xyscan/jammy 4.61-1 amd64
# xz-utils/jammy-updates,jammy-security 5.2.5-2ubuntu1.1 amd64 [upgradable from: 5.2.5-2ubuntu1]
# xzdec/jammy-updates,jammy-security 5.2.5-2ubuntu1.1 amd64
# xzgv/jammy 0.9.2-2build1 amd64
# xzip/jammy 1:1.8.2-4build1 amd64
# xzoom/jammy 0.3-26 amd64
# yabar/jammy 0.4.0-1.1 amd64
# yabasic/jammy 1:2.90.2-1 amd64
# yabause-common/jammy 0.9.14-4build2 all
# yabause-gtk/jammy 0.9.14-4build2 amd64
# yabause-qt/jammy 0.9.14-4build2 amd64
# yabause/jammy 0.9.14-4build2 all
# yacas-doc/jammy 1.3.6-2.1 all
# yacas/jammy 1.3.6-2.1 amd64
# yacpi/jammy 3.0.1-2 amd64
# yad/jammy 0.40.0-1build1 amd64
# yade-doc/jammy 2022.01a-7 all
# yade/jammy 2022.01a-7 amd64
# yadifa/jammy 2.4.2-1build1 amd64
# yadm/jammy 3.1.1-1 all
# yaegi/jammy 0.10.0-2 amd64
# yafc/jammy 1.3.7-4build2 amd64
# yagf/jammy 0.9.5+repack1-1 amd64
# yaggo/jammy 1.5.10-5 all
# yagiuda/jammy 1.19-10 amd64
# yagv/jammy 0.4~20171211.r234ef16+dfsg-2 all
# yaha/jammy 0.1.83-3 amd64
# yahtzeesharp/jammy 1.1-6.1 all
# yajl-tools/jammy-updates,jammy-security 2.1.0-3ubuntu0.22.04.1 amd64
# yakuake/jammy 21.12.3-1ubuntu1 amd64
# yale/jammy 5.0.95-2 all
# yamagi-quake2-core/jammy 8.01+ctf1.08~dfsg-1 amd64
# yamagi-quake2/jammy 8.01+ctf1.08~dfsg-1 amd64
# yamdi/jammy 1.4-3 amd64
# yamllint/jammy 1.26.3-1 all
# yample/jammy 0.30-3.1 all
# yanagiba/jammy 1.0.0-5 all
# yang-tools/jammy 1.0.225-1.1 all
# yangcli/jammy 2.12-1build1 amd64
# yangdump/jammy 2.12-1build1 amd64
# yank/jammy 1.2.0-1 amd64
# yanosim/jammy 0.1-4 amd64
# yapet/jammy 2.6-1 amd64
# yapf3/jammy 0.32.0-1 all
# yapps2/jammy 2.2.1-3.1 all
# yapra/jammy 0.1.2-7.1 all
# yara-doc/jammy 4.1.3-1build1 all
# yara/jammy 4.1.3-1build1 amd64
# yard-doc/jammy-updates,jammy-security 0.9.26-1ubuntu0.1 all
# yard/jammy-updates,jammy-security 0.9.26-1ubuntu0.1 all
# yaret/jammy 2.1.0-5.1 all
# yarnpkg/jammy 1.22.10+~cs22.25.14-8 all
# yaru-theme-gnome-shell/jammy-updates 22.04.5 all
# yaru-theme-gtk/jammy-updates 22.04.5 all
# yaru-theme-icon/jammy-updates 22.04.5 all
# yaru-theme-sound/jammy-updates 22.04.5 all
# yaru-theme-unity/jammy-updates 22.04.5 all
# yasat/jammy 848-1.1 all
# yash/jammy 2.51-1 amd64
# yaskkserv/jammy 1.1.1-1build1 amd64
# yasm/jammy 1.3.0-2.1 amd64
# yasnippet/jammy 0.14.0+git20200603.5cbdbf0d-1 all
# yasr/jammy 0.6.9-10 amd64
# yasw/jammy 0.6-2build1 amd64
# yatex/jammy 1.82-1 all
# yatm/jammy 0.9-3 amd64
# yavta/jammy 0.0+git20210522.65f740a-1 amd64
# yaws-chat/jammy 2.1.1+dfsg-1 all
# yaws-doc/jammy 2.1.1+dfsg-1 all
# yaws-mail/jammy 2.1.1+dfsg-1 all
# yaws-wiki/jammy 2.1.1+dfsg-1 all
# yaws-yapp/jammy 2.1.1+dfsg-1 all
# yaws/jammy 2.1.1+dfsg-1 all
# yaz-doc/jammy 5.31.1-1build1 all
# yaz-icu/jammy 5.31.1-1build1 amd64
# yaz-illclient/jammy 5.31.1-1build1 amd64
# yaz/jammy 5.31.1-1build1 amd64
# yazc/jammy 0.4.3-1 amd64
# yc-el/jammy 5.0.0-8.1 amd64
# ycm-cmake-modules/jammy 0.13.0-2 all
# ycmd/jammy 0+20201028+git1d415c5+ds-1build2 amd64
# ydotool/jammy 0.1.8-3 amd64
# ydotoold/jammy 0.1.8-3 amd64
# ydpdict/jammy 1.0.3-1 amd64
# yeahconsole/jammy 0.3.4-6 amd64
# yelp-tools/jammy 42.0-1 all
# yelp-xsl/jammy-updates,jammy-security 42.0-1ubuntu0.1 all
# yelp/jammy-updates,jammy-security 42.1-1ubuntu0.1 amd64
# yersinia/jammy 0.8.2-2.1build1 amd64
# yesod/jammy 1.6.0.6-1build1 amd64
# yforth/jammy 0.2.1-1build1 amd64
# yggdrasil/jammy-updates,jammy-security 0.4.3-2ubuntu0.22.04.3 amd64
# yi/jammy 0.19.0-1build1 amd64
# yiyantang/jammy 0.7.0-8 amd64
# ykcs11/jammy 2.2.0-1ubuntu1 amd64
# ykls/jammy 1.3.4-2 amd64
# ykush-control/jammy 1.2.5+ds-1 amd64
# ylva/jammy 1.7-1build1 amd64
# ynew/jammy 1.2-1 all
# yodl-doc/jammy 4.03.02-2 all
# yodl/jammy 4.03.02-2 amd64
# yokadi/jammy 1.2.0-3 all
# yorick-av/jammy 0.0.6-1 amd64
# yorick-cubeview/jammy 2.2-2.2 all
# yorick-curses/jammy 0.1-6build2 amd64
# yorick-data/jammy 2.2.04+dfsg1-12 all
# yorick-dev/jammy 2.2.04+dfsg1-12 amd64
# yorick-doc/jammy 2.2.04+dfsg1-12 all
# yorick-full/jammy 2.2.04+dfsg1+full amd64
# yorick-gl/jammy 1.1+cvs20070922+dfsg-6.1 amd64
# yorick-gy/jammy 0.0.5-2 amd64
# yorick-gyoto/jammy 1.4.4-7build1 amd64
# yorick-hdf5/jammy 0.8.0-8build2 amd64
# yorick-imutil/jammy 0.5.7-3 amd64
# yorick-mira/jammy 1.1.0+git20170124.3bd1c3~dfsg1-2 all
# yorick-ml4/jammy 0.6.0-4 amd64
# yorick-mpeg/jammy 0.1-3 amd64
# yorick-mpy-common/jammy 2.2.04+dfsg1-12 all
# yorick-mpy-mpich2/jammy 2.2.04+dfsg1-12 amd64
# yorick-mpy-openmpi/jammy 2.2.04+dfsg1-12 amd64
# yorick-optimpack/jammy 1.3.2+dfsg+1.4.0-1 amd64
# yorick-soy/jammy 1.4.0-3 amd64
# yorick-svipc/jammy 0.16-5build5 amd64
# yorick-yeti-fftw/jammy 6.4.0-1 amd64
# yorick-yeti-regex/jammy 6.4.0-1 amd64
# yorick-yeti-tiff/jammy 6.4.0-1 amd64
# yorick-yeti/jammy 6.4.0-1 amd64
# yorick-ygsl/jammy 1.2.1-1build3 amd64
# yorick-ynfft/jammy 1.0.3-1 amd64
# yorick-yutils/jammy 1.5.2-2 all
# yorick-z/jammy 1.2.0+cvs20080115-5.1 amd64
# yorick/jammy 2.2.04+dfsg1-12 amd64
# yoshimi-data/jammy 2.1.2.2~dfsg0-1 all
# yoshimi-doc/jammy 2.1.2.2~dfsg0-1 all
# yoshimi/jammy 2.1.2.2~dfsg0-1 amd64
# yosys-dev/jammy 0.9-2 amd64
# yosys-doc/jammy 0.9-2 all
# yosys/jammy 0.9-2 amd64
# yotta-doc/jammy 0.20.5-5 all
# yotta/jammy 0.20.5-5 all
# youker-assistant/jammy 3.0.2.1-0ubuntu1 amd64
# youtube-dl/jammy 2021.12.17-1 all
# youtubedl-gui/jammy 3.0-1 amd64
# yowsup-cli/jammy 3.2.3-2 all
# yoyo/jammy 7.3.2+dfsg1-2 all
# yp-tools/jammy 4.2.3-3 amd64
# ypbind-mt/jammy 2.7.2-2 amd64
# ypserv/jammy 4.1-2 amd64
# yrmcds/jammy 1.1.9-1 amd64
# yt-dlp/jammy 2022.04.08-1 all
# ytcc/jammy 2.5.4-1 all
# ytnef-tools/jammy 2.0-1 amd64
# ytree/jammy 1.99pl1-2 amd64
# yubico-piv-tool/jammy 2.2.0-1ubuntu1 amd64
# yubikey-agent/jammy-updates,jammy-security 0.1.4-2ubuntu0.22.04.1 amd64
# yubikey-luks/jammy 0.5.1+29.g5df2b95-6build1 all
# yubikey-manager-qt/jammy 1.2.4-1 amd64
# yubikey-manager/jammy 4.0.7-1 all
# yubikey-personalization-gui/jammy 3.1.24-1build1 amd64
# yubikey-personalization/jammy 1.20.0-3 amd64
# yubioath-desktop/jammy 5.1.0-1 amd64
# yubiserver/jammy 0.6-3.1 amd64
# yudit-common/jammy 3.0.7-3 all
# yudit-doc/jammy 3.0.7-3 all
# yudit/jammy 3.0.7-3 amd64
# yui-compressor/jammy 2.4.8-2.1 all
# yum4/jammy 4.5.2-6 all
# yuview/jammy 2.9-1 amd64
# yuyo-gtk-theme/jammy 0.3 all
# yydebug/jammy 1.1.0-13 all
# z-push-backend-caldav/jammy 2.6.0-1 all
# z-push-backend-carddav/jammy 2.6.0-1 all
# z-push-backend-combined/jammy 2.6.0-1 all
# z-push-backend-galsearch-ldap/jammy 2.6.0-1 all
# z-push-backend-imap/jammy 2.6.0-1 all
# z-push-backend-kopano/jammy 2.6.0-1 all
# z-push-backend-ldap/jammy 2.6.0-1 all
# z-push-common/jammy 2.6.0-1 all
# z-push-ipc-memcached/jammy 2.6.0-1 all
# z-push-kopano-gab2contacts/jammy 2.6.0-1 all
# z-push-kopano-gabsync/jammy 2.6.0-1 all
# z-push-state-sql/jammy 2.6.0-1 all
# z-push/jammy 2.6.0-1 all
# z3/jammy 4.8.12-1 amd64
# z80asm/jammy 1.8-1build1 amd64
# z80dasm/jammy 1.1.6-1 amd64
# z8530-utils2/jammy 3.0-1-10 amd64
# z88-data/jammy 13.0.0+dfsg2-6 all
# z88-doc/jammy 13.0.0+dfsg2-6 all
# z88/jammy 13.0.0+dfsg2-6 amd64
# zabbix-agent/jammy 1:5.0.17+dfsg-1 amd64
# zabbix-frontend-php/jammy 1:5.0.17+dfsg-1 all
# zabbix-java-gateway/jammy 1:5.0.17+dfsg-1 all
# zabbix-proxy-mysql/jammy 1:5.0.17+dfsg-1 amd64
# zabbix-proxy-pgsql/jammy 1:5.0.17+dfsg-1 amd64
# zabbix-proxy-sqlite3/jammy 1:5.0.17+dfsg-1 amd64
# zabbix-server-mysql/jammy 1:5.0.17+dfsg-1 amd64
# zabbix-server-pgsql/jammy 1:5.0.17+dfsg-1 amd64
# zalign/jammy 0.9.1-5 amd64
# zam-plugins/jammy 3.14~repack3-1 amd64
# zangband-data/jammy 1:2.7.5pre1-13 all
# zangband/jammy 1:2.7.5pre1-13 amd64
# zanshin/jammy 21.12.3-0ubuntu1 amd64
# zaqar-common/jammy 14.0.0-0ubuntu1 all
# zaqar-server/jammy 14.0.0-0ubuntu1 all
# zaqar-tempest-plugin/jammy 1.3.1-2 all
# zatacka/jammy 0.1.8-7 amd64
# zathura-cb/jammy 0.1.9-2 amd64
# zathura-dev/jammy 0.4.9-1 amd64
# zathura-djvu/jammy 0.2.9-1 amd64
# zathura-pdf-poppler/jammy 0.3.0-1build1 amd64
# zathura-ps/jammy 0.2.7-2 amd64
# zathura/jammy 0.4.9-1 amd64
# zaz-data/jammy 1.0.1-1 all
# zaz/jammy 1.0.1-1 amd64
# zbackup/jammy 1.5-1build1 amd64
# zbar-tools/jammy 0.23.92-4build2 amd64
# zbarcam-gtk/jammy 0.23.92-4build2 amd64
# zbarcam-qt/jammy 0.23.92-4build2 amd64
# zbd-utils/jammy 2.0.2-2 amd64
# zchunk/jammy 1.1.16+ds1-1 amd64
# zdbsp/jammy 1.19+20181027+dfsg.1-2build1 amd64
# zeal/jammy 1:0.6.1-1.2 amd64
# zec/jammy 0.12-5 all
# zeek-aux/jammy 0.45-1 amd64
# zegrapher/jammy 3.1.1-2 amd64
# zeitgeist-core/jammy 1.0.3-4ubuntu1 amd64
# zeitgeist-datahub/jammy 1.0.3-4ubuntu1 amd64
# zeitgeist/jammy 1.0.3-4ubuntu1 all
# zemberek-java-demo/jammy 2.1.1-8.3 all
# zemberek-server/jammy 0.7.1-12.3 all
# zenity-common/jammy-updates 3.42.1-0ubuntu1 all
# zenity/jammy-updates 3.42.1-0ubuntu1 amd64
# zenlisp/jammy 2013.11.22-3 amd64
# zephyr-clients/jammy 3.1.2-1build3 amd64
# zephyr-server-krb5/jammy 3.1.2-1build3 amd64
# zephyr-server/jammy 3.1.2-1build3 amd64
# zeroc-glacier2/jammy 3.7.6-4ubuntu1 amd64
# zeroc-ice-all-dev/jammy 3.7.6-4ubuntu1 all
# zeroc-ice-all-runtime/jammy 3.7.6-4ubuntu1 all
# zeroc-ice-compilers/jammy 3.7.6-4ubuntu1 amd64
# zeroc-ice-manual/jammy 3.5.0-1 all
# zeroc-ice-slice/jammy 3.7.6-4ubuntu1 all
# zeroc-ice-utils-java/jammy 3.7.6-4ubuntu1 all
# zeroc-ice-utils/jammy 3.7.6-4ubuntu1 amd64
# zeroc-icebox/jammy 3.7.6-4ubuntu1 amd64
# zeroc-icebridge/jammy 3.7.6-4ubuntu1 amd64
# zeroc-icegrid/jammy 3.7.6-4ubuntu1 amd64
# zeroc-icegridgui/jammy 3.7.6-4ubuntu1 all
# zeroc-icepatch2/jammy 3.7.6-4ubuntu1 amd64
# zerofree/jammy 1.1.1-1build3 amd64
# zfcp-hbaapi-dev/jammy-updates 2.2.0-0ubuntu1.1 amd64
# zfcp-hbaapi-utils/jammy-updates 2.2.0-0ubuntu1.1 amd64
# zfs-auto-snapshot/jammy 1.2.4-2 all
# zfs-dkms/jammy-updates 2.1.5-1ubuntu6~22.04.6 all
# zfs-dracut/jammy-updates 2.1.5-1ubuntu6~22.04.6 amd64
# zfs-fuse/jammy 0.7.0-22ubuntu1 amd64
# zfs-initramfs/jammy-updates 2.1.5-1ubuntu6~22.04.6 amd64
# zfs-test/jammy-updates 2.1.5-1ubuntu6~22.04.6 amd64
# zfs-zed/jammy-updates 2.1.5-1ubuntu6~22.04.6 amd64
# zfsnap/jammy 1.11.1-5.1 all
# zfsutils-linux/jammy-updates 2.1.5-1ubuntu6~22.04.6 amd64
# zgen/jammy 0~20150919-3.1 all
# zh-autoconvert/jammy 0.3.16-7 amd64
# zhcon-data/jammy 1:0.2.6-19 all
# zhcon/jammy 1:0.2.6-19 amd64
# zile/jammy 2.6.2-2 amd64
# zim-tools/jammy 3.1.0-3 amd64
# zim/jammy 0.74.3-1 all
# zimwriterfs/jammy 3.1.0-3 all
# zinnia-utils/jammy 0.06-6ubuntu2 amd64
# zint-qt/jammy 2.10.0-1 amd64
# zint/jammy 2.10.0-1 amd64
# zip/jammy,now 3.0-12build2 amd64 [installed]
# zipalign/jammy 1:10.0.0+r36-1 amd64
# zipcmp/jammy 1.7.3-1ubuntu2 amd64
# zipmerge/jammy 1.7.3-1ubuntu2 amd64
# zipper.app/jammy 1.5-3build3 amd64
# ziproxy/jammy 3.3.2-2 amd64
# ziptime/jammy 1:10.0.0+r36-1 amd64
# ziptool/jammy 1.7.3-1ubuntu2 amd64
# zita-ajbridge/jammy 0.8.4-1 amd64
# zita-alsa-pcmi-utils/jammy 0.4.0-1 amd64
# zita-at1/jammy 0.6.2-2 amd64
# zita-bls1/jammy 0.3.3-3 amd64
# zita-dc1/jammy 0.3.3-1 amd64
# zita-dpl1/jammy 0.3.3-1 amd64
# zita-lrx/jammy 0.1.2-1build1 amd64
# zita-mu1/jammy 0.3.3-2 amd64
# zita-njbridge/jammy 0.4.8-1 amd64
# zita-resampler/jammy 1.8.0-2 amd64
# zita-rev1/jammy 0.2.2-2 amd64
# zkg/jammy 2.12.0-1 all
# zktop/jammy 1.0.0-4 all
# zlib-gst/jammy 3.2.5-1.3ubuntu1 amd64
# zlib1g-dev/jammy-updates,jammy-security,now 1:1.2.11.dfsg-2ubuntu9.2 amd64 [installed,automatic]
# zlib1g/jammy-updates,jammy-security,now 1:1.2.11.dfsg-2ubuntu9.2 amd64 [installed]
# zmakebas/jammy 1.2-1.1build1 amd64
# zmap/jammy 2.1.1-2build4 amd64
# zmf2epub/jammy 0.9.6-3 amd64
# zmf2odg/jammy 0.9.6-3 amd64
# zmk-doc/jammy 0.5.1-2 all
# zmk/jammy 0.5.1-2 all
# znc-backlog/jammy-updates,jammy-security 0.20180824+1.8.2-2ubuntu0.1 amd64
# znc-dev/jammy-updates,jammy-security 1.8.2-2ubuntu0.1 amd64
# znc-perl/jammy-updates,jammy-security 1.8.2-2ubuntu0.1 amd64
# znc-push/jammy-updates,jammy-security 1.0.0+git20190521.78d0385+1.8.2-2ubuntu0.1 amd64
# znc-python/jammy-updates,jammy-security 1.8.2-2ubuntu0.1 amd64
# znc-tcl/jammy-updates,jammy-security 1.8.2-2ubuntu0.1 amd64
# znc/jammy-updates,jammy-security 1.8.2-2ubuntu0.1 amd64
# zoem/jammy 11-166-2 amd64
# zomg/jammy 0.8.1-3 amd64
# zonemaster-cli/jammy 1.0.5-1.1 all
# zoneminder-doc/jammy 1.36.12+dfsg1-1 all
# zoneminder/jammy 1.36.12+dfsg1-1 amd64
# zoo-api/jammy 1.9.0+ds-1~jammy3 amd64
# zoo-kernel/jammy 1.9.0+ds-1~jammy3 amd64
# zoo-service-ogr/jammy 1.9.0+ds-1~jammy3 amd64
# zoo-service-openapi/jammy 1.9.0+ds-1~jammy3 amd64
# zoo-service-otb/jammy 1.9.0+ds-1~jammy3 amd64
# zoo-service-status/jammy 1.9.0+ds-1~jammy3 amd64
# zoo-services/jammy 1.9.0+ds-1~jammy3 amd64
# zookeeper-bin/jammy-updates,jammy-security 3.4.13-6ubuntu4.1 amd64
# zookeeper/jammy-updates,jammy-security 3.4.13-6ubuntu4.1 all
# zookeeperd/jammy-updates,jammy-security 3.4.13-6ubuntu4.1 all
# zoom-player/jammy 1.1.5~dfsg-6 amd64
# zopfli/jammy 1.0.3-1build1 amd64
# zoph/jammy 0.9.19-1 all
# zoxide/jammy 0.4.3-2 amd64
# zpaq/jammy 7.15+repack-1 amd64
# zplug/jammy 2.4.2-1 all
# zpspell/jammy 0.4.3-4.1build2 amd64
# zram-config/jammy 0.7build1 all
# zram-tools/jammy 0.3.3.1-1 all
# zsh-antigen/jammy 2.2.3-5 all
# zsh-autosuggestions/jammy 0.7.0-1 all
# zsh-common/jammy 5.8.1-1 all
# zsh-dev/jammy 5.8.1-1 amd64
# zsh-doc/jammy 5.8.1-1 all
# zsh-static/jammy 5.8.1-1 amd64
# zsh-syntax-highlighting/jammy 0.7.1-2 all
# zsh-theme-powerlevel9k/jammy 0.6.7-2 all
# zsh/jammy 5.8.1-1 amd64
# zsnapd-rcmd/jammy 0.8.12-1 all
# zsnapd/jammy 0.8.12-1 all
# zssh/jammy 1.5c.debian.1-8 amd64
# zstd/jammy 1.4.8+dfsg-3build1 amd64
# zsync/jammy 0.6.2-3ubuntu1 amd64
# zsys/jammy-updates,jammy-security 0.5.9ubuntu0.22.04.1 amd64
# ztclocalagent/jammy 5.0.0.30-0ubuntu3 amd64
# ztex-bmp/jammy 20120314-2 amd64
# zulucrypt-cli/jammy 5.7.1-2 amd64
# zulucrypt-gui/jammy 5.7.1-2 amd64
# zulumount-cli/jammy 5.7.1-2 amd64
# zulumount-gui/jammy 5.7.1-2 amd64
# zulupolkit/jammy 5.7.1-2 amd64
# zulusafe-cli/jammy 5.7.1-2 amd64
# zurl/jammy 1.11.1-1 amd64
# zutils/jammy 1.11-1 amd64
# zutty/jammy 0.11.2.20220109.192032+dfsg1-1 amd64
# zvbi/jammy 0.2.35-19 amd64
# zvmcloudconnector-api/jammy 2.0.0~b1~git2019062011.4fc9142.really.1.4.1-0ubuntu3 all
# zvmcloudconnector-common/jammy 2.0.0~b1~git2019062011.4fc9142.really.1.4.1-0ubuntu3 all
# zydis-tools/jammy 3.2.1-5 amd64
# zynaddsubfx-data/jammy 3.0.5-2build1 all
# zynaddsubfx-dssi/jammy 3.0.5-2build1 amd64
# zynaddsubfx-lv2/jammy 3.0.5-2build1 amd64
# zynaddsubfx-vst/jammy 3.0.5-2build1 amd64
# zynaddsubfx/jammy 3.0.5-2build1 amd64
# zypper-common/jammy 1.14.42-2 all
# zypper-doc/jammy 1.14.42-2 all
# zypper/jammy 1.14.42-2 amd64
# zytrax/jammy 0+git20201215-1 amd64
# zziplib-bin/jammy 0.13.72+dfsg.1-1.1 amd64

# %% [markdown]
# Note that they are sometimes not the latest ones. It is probably because they prefer to install the well-tested ones.
#
# If you want to use the one not on the list, you can install it by pip / apt (as you are the root user).

# %% [markdown]
# #Other choices
#
# Every year, many things have happend, so honestly speaking, I cannot tell what are the good alternative choices.
# Some of the alternative (conventional) environment choices for AI learners are:
#
# * [Amazon AWS Sagemaker Studio Lab](https://aws.amazon.com/jp/sagemaker/studio-lab/)
#
# * [Microsoft Learn](https://learn.microsoft.com/)
#
# * [IBM watson studio](https://www.ibm.com/products/watson-studio)
#
# * [Matlab 機械学習](https://jp.mathworks.com/help/stats/machine-learning-in-matlab.html)

# %% [markdown]
# ---
# Back to [index](https://github.com/kameda-yoshinari/IMISToolExeA/)
#
# ---
# Tools and Practices for Intelligent Interaction Systems A
# Master's and Docotal programs in intelligent and mechanical interaction systems, University of Tsukuba, Japan.
# KAMEDA Yoshinari, SHIBUYA Takeshi
#
# 知能システムツール演習a
# 知能機能システム学位プログラム (筑波大学大学院)
# 担当：亀田能成，澁谷長史
#
# 2026/07/27.
# 2024/07/04.
# 2023/07/13.
# 2021/08/01.
# 2021/07/26.
# 2020/06/29.
